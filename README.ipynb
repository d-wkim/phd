# %% [markdown]
# <!-- Notes:
#
# Read this and follow the steps to organize and stuff.
# https://medium.com/@caneuenschwander/how-to-turn-a-messy-jupyter-notebook-into-a-professional-python-project-f34d5ee7f88b
#
#
#
# -->

# %% [markdown]
# [![PythonAnywhere](https://img.shields.io/badge/PythonAnywhere-3776AB?style=for-the-badge&logo=pythonanywhere&logoColor=fff)](https://www.pythonanywhere.com/user/dongwkim/)
# [![Anaconda](https://img.shields.io/badge/Anaconda_Cloud-44A833?style=for-the-badge&logo=anaconda&logoColor=fff)](https://anaconda.com/app/)
# [![JupyterLite](https://img.shields.io/badge/JupyterLite-yellow?style=for-the-badge&logo=jupyter&logoColor=fff)](https://dong-wkim.github.io/jupyterlite/lab/index.html)

# %% [markdown]
# <div align="center">
# <a href="#systematic_review"><img alt="Systematic Review" src="https://img.shields.io/badge/Systematic_Review-black?style=for-the-badge&logo=jupyter&logoColor=white"/></a>
# <a href="#data_collection"><img alt="Data Collection" src="https://img.shields.io/badge/Data_Collection-black?style=for-the-badge" /></a>
# <a href="#meta_analysis"><img alt="Meta-Analysis" src="https://img.shields.io/badge/Meta_Analysis-black?style=for-the-badge" /></a>
# <a href="#manuscript"><img alt="Manuscript" src="https://img.shields.io/badge/Manuscript-black?style=for-the-badge" /></a>
# </div>
#
# <br />
# <br />
# <!-- Target -->
# <a id="titlepage"></a>
#
# <!-- 1. University Name (English) -->
# <div align = "center" style = "font-family: Times New Roman; font-variant: small-caps;"><h5>Jagiellonian University<br>Medical College<br>Doctoral School of Medical and Health Sciences</h5></div></br>
#
# <!-- 2. Logo -->
# <div align = "center"><a href="https://dongwkim.com"><img src="https://raw.githubusercontent.com/dong-wkim/assets/refs/heads/master/logos/uj_logo.jpg" alt="Logo" width="100" height="100"></a></div>
# <hr style = "background-color:gray; height: 1.5px;">
#
# <!-- 3. Title -->
# <div align="center" style="font-family:Times New Roman;"><h2>Comparative analysis of outcome measures using<br>the most commonly used graft harvesting sources in<br> primary anterior cruciate ligament reconstruction surgery. </h2></div>
#
# <!-- 4. Subtitle -->
# <div align="center" style="font-family:Times New Roman;"><h4><i>A systematic review and network meta-analysis<i></h4></div>
# <hr style = "background-color:black; height: 1.5px;">
#
# <div align="center" style="font-family:Times New Roman;">
#     <h6>A dissertation submitted in partial fulfillment of the requirements for the award of the degree of:</h6><h5>Doctor of Philosophy (Ph.D.)</h5><h6><i>submitted by:</i></h6><br>
# </div>
#
# <!-- 5. Author -->
# <div align = "center" style="font-family:Times New Roman;">
#     <h4 size = 20><b>Dong Woon Kim, M.D.</b><sup>1,2,3</sup></h4>
#     <h6><i>dr n. med. Dong Woon Kim</i></h6></div><br>
#
# <!-- 6. Supervisor -->
# <div align = "center"><h6 style="font-family:Times New Roman;"><i>supervised by:</i></sub></div>
# <div align = "center"><sub style="font-family:Times New Roman;">Konrad Malinowski, M.D., Ph.D<sup>1,4</sup></sub></div>
# </div>
# <br>
# <br>
# <div align = "center" style = "font-family: Times New Roman;"><h6>Kraków, 2026</h6></div>
# <div>
#
# <div align = "left" style = "font-family: Times New Roman;">
#
# <p>_________________________________________</p>
#     <font family = "Times New Roman" size = "1em">
#         <sup>1</sup> Department of Anatomy, Jagiellonian University, Kraków, Poland  <br/>
#         <sup>2</sup> Whiting College of Engineering, Johns Hopkins University, Baltimore, MD, United States  <br/>
#         <sup>3</sup> Harvard University, Cambridge, MA, United States<br>
#         <sup>4</sup> Artromedical Orthopedic Clinic, Bełchatów, Poland
#     </font>
# </div>

# %%
import subprocess
import sys
import os
import pandas as pd
from Bio import Entrez, Medline
import ssl
import certifi
import re
from pathlib import Path

# %%
from src.custom_scripts import csv, markdown_to_html, df_to_markdown_table, static_badge, requirements, mkdir

# %%
folders = {
    "docs": f"./docs", 
    "notebooks": f"./notebooks"
}

mkdir(folders)

# %% [markdown]
# <a id="systematic_review"></a>
# <hr style="border: none; height: 1.5px; background-color: black;">
# <a href="#titlepage"><img alt="Previous" src="https://img.shields.io/badge/Previous-blue?style=for-the-badge"  height="60"></a>
# <a href="#titlepage"><img alt="Top" src="https://img.shields.io/badge/Top-blue?style=for-the-badge"  height="40"></a>
# <a href="#titlepage"><img alt="Next" src="https://img.shields.io/badge/Next-blue?style=for-the-badge"  height="40"></a>
#
# <div align="center">
# <h2 style="font-family:Times New Roman;font-variant:small-caps;">Systematic Review</h2></div>
#
# <br/>
# <div align = "center">
# <a href="#protocol"><img alt="Protocol" src="https://img.shields.io/badge/Protocol-black?style=for-the-badge" /></a>
# <a href="#search_strategy"><img alt="Search Strategy" src="https://img.shields.io/badge/Search_Strategy-black?style=for-the-badge" /></a>
# <a href="#search"><img alt="Search" src="https://img.shields.io/badge/Search-black?style=for-the-badge" /></a>
# <a href="#deduplication"><img alt="Deduplication" src="https://img.shields.io/badge/Deduplication-black?style=for-the-badge" /></a>
# <a href="#screening"><img alt="Screening" src="https://img.shields.io/badge/Screening-black?style=for-the-badge" /></a>
# <a href="#title_abstract_screening"><img alt="Title abstract screening" src="https://img.shields.io/badge/Title_abstract_screening-black?style=for-the-badge&logo=&logoColor="/></a>
# </div>

# %% [markdown]
# <a id="protocol"></a>
#
# <div align="center">
#     <h2 align="center" style="font-family:Times New Roman;font-variant: small-caps;">Protocol</h2></br></div>
#
# <div align="center">
#     <a href="#cochrane"><img alt="Cochrane" src="https://img.shields.io/badge/Cochrane-black?style=for-the-badge"  width="100"></a>
#     <a href="https://www.crd.york.ac.uk/PROSPERO/view/CRD42024592549"><img alt="PROSPERO" src="https://img.shields.io/badge/PROSPERO-black?style=for-the-badge"  width="100"></a>
# </div>
#
# <hr style="border: none; height: 0.5px; background-color: black;">

# %% [markdown]
# <a id="cochrane"></a>
#
# <div align="left">
#     <h3 align="left" style="font-family:Times New Roman;font-variant: small-caps;">Cochrane Reviews</h3>
# <p style="font-size: 12px; font-family:Times New Roman;">COCHRANEEMD-2026-00379</p>
# </div>

# %% [markdown]
# **Research question**
#
# The proposed review answers the question of whether graft choice plays a factor in
# determining outcomes after primary anterior cruciate ligament reconstruction surgery. And if so, which outcomes are affected by which grafts, as well as the degree of effect specific graft have on each outcome(s) that is/are found to have statistically significant differences in effect sizes. Finally, it answers whether controlling for gender, age and follow-up duration have any effect on the results of the study

# %% [markdown]
# **Rationale**
#
# The current state of knowledge in literature is that there are gold standard surgical techniques for primary anterior cruciate ligament reconstruction surgery in terms of specific grafts and suspension/fixation techniques and tools; however, as advancements in the latter over recent years has opened the door for all soft-tissue and even allogenic grafts as just as viable—if not better—alternative graft choices.
#
# Specifically, the bone-patellar tendon-bone and hamstring tendon autologous grafts
# have been tried-and-tested and consensus had deemed these two grafts as the 'gold
# standard' choice for orthopedic surgeons. However, the quadriceps
# tendon—particularly without the bony attachment—was found to produce non-inferior
# results compared to those with the patellar bone attachment. This finding opens the
# door for comparing all soft-tissue grafts with other that share this similar characteristic, such as the hamstring and peroneus longus tendon autologous grafts. As there are numerous studies comparing the various grafts, but not one comprehensive source from which to guide evidence-based practice, this review paper seeks to add to fill this gap in current knowledge by comparing the available randomized controlled trials to produce an evidence level I network meta-analysis to guide clinicians in their practice.

# %% [markdown]
# **Objectives**
#
# This is an important question because total knee arthroplasty (TKA), or total knee replacement is one of the most commonly performed surgical operations in the world. However, studies have found a sole indication for such a procedure, and that is osteoarthritic knee pain. Pain that is chronic, and strong in intensity that it permanently degrades the indicated patients' quality of lives. TKA, however, also limits patients' locomotive capabilities, and is not a procedure that is synonymous with restorative.
#
# The most commonly cited research topic in orthopedic surgery by orthopedics
# surgeons was anterior cruciate ligament reconstruction (ACLR) surgery, with the link between this and TKA being that the former (ACLR) is the most common cause of non-degenerative and thus, the most common modifiable risk factor for preventing TKA and osteoarthritis. If we are able to answer certain questions through research, then we can advance our collective body of knowledge surrounding one of the most debilitating musculoskeletal conditions and preventing those from developing osteoarthritis after ACLR.

# %% [markdown]
# **Eligibility criteria**
#
# |     | Categories   | Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          | Inclusion criteria                                                                                                                                                               | Exclusion criteria                                       |
# |:----|:-------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------|
# | P   | Population   | Adult patients with post-traumatic grade III (complete tear) of unilateral anterior cruciateligament are included. Both genders are included, and upper limit in age is unrestricted. Only studies with mean age greater than or equal to 18 years old across all patients will be presumed to have targeted a population that is considered skeletally-mature.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      | Adult patients                                                                                                                                                                   | Pediatric patients                                       |
# | I   | Intervention | Primary anterior cruciate ligament reconstruction (ACLR) surgeries are included. ACLRs performed simultaneously on both knees, in conjunction with other ligamental reconstructions aside from meniscal, and revision ACLRs were excluded.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | Primary ACLR                                                                                                                                                                     | Revision ACLR or ACL repair (BEAR)                       |
# | C   | Comparators  | Autologous grafts: bone-patellar tendon-bone, hamstring tendon, quadriceps tendon,and peroneus longus tendon are included. Allogenic grafts: Achilles tendon and tibialis anterior and posterior are also included. All other graft types, such as synthetic grafts and allogenic versions of commonly used autologous ones are excluded (the Achillesand tibialis tendon grafts are included despite being allogenic because autologous versions cannot be grafted in patients due to the important roles the muscle from whichthe tendon is attached plays in normal physiologic biomechanics).                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    | Bone-patellar tendon-bone, hamstring tendon, quadriceps, or peroneus longus tendon autologous grafts, or Achilles tendon or tibialis anterior/posterior tendon allogenic grafts. | All other graft types (LET)                              |
# | O   | Outcomes     | The outcomes of interest were measures of (1) patient-reported outcome measures(PROMs) of patient satisfaction as surrogate measure for subjective quality oflife—answering the question of how much is the patient able to live as close to preinjury state; (2) Objective measures of translational and rotational knee stability; and(3) Adverse events and complications. In (1), the primary (most commonly reported) outcomes were included: IKDC subjective knee form (SKF), Lysholm and Tegner. For(2), instrumental laxity (side-to-side difference in millimeters) of antero-posterior translation by the anterior drawer test, pivot shift and Lachman tests were included. For(3) graft failure, including re-re-rupture of graft (confirmed via imaging), clinical failure(defined by clinical failure during objective measures) and revision surgeries(arthroscopic confirmation of tears).Other outcomes that were excluded were due to their deemed incompatibility forcomparisons across all grafts. For example, hamstring and quadriceps muscle strength recovery is not a relevant outcome measure for determining effectiveness of ACLR when comparing across grafts in which some were not taken from the patients' hamstring or quadriceps muscle, or is a component that disrupts such biomechanicalphysiology. Donor site morbidity is another example of an outcome that may be out ofrange in scope, due to the variety of definitions for consistent applicability incomparisons. Other outcomes such as Marx, KOOS, VAS, were excluded due to thelow number of studies that reported these outcome measures, in comparison to theother ones that surrogatively measure the same thing. | Primary outcomes of interest: IKDC subjective, Lysholm, Tegner, pivot shift, Lachman, instrumental laxity, graft rupture, graft failure, revision rate                           | Secondary outcomes of interest                           |
# | S   | Study Design | Only randomized controlled trials will be included into the qualitative and quantitative portions of the review.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     | Randomized controlled trials                                                                                                                                                     | Non-randomized clinical trials and observational studies |

# %% [markdown]
# <div align = "center">
# <a href="#protocol"><img alt="Protocol" src="https://img.shields.io/badge/Protocol-black?style=for-the-badge" /></a>
# <a href="#search_strategy"><img alt="Search Strategy" src="https://img.shields.io/badge/Search_Strategy-black?style=for-the-badge" /></a>
# <a href="#search"><img alt="Search" src="https://img.shields.io/badge/Search-black?style=for-the-badge" /></a>
# <a href="#deduplication"><img alt="Deduplication" src="https://img.shields.io/badge/Deduplication-black?style=for-the-badge" /></a>
# <a href="#screening"><img alt="Screening" src="https://img.shields.io/badge/Screening-black?style=for-the-badge" /></a>
# <a href="#title_abstract_screening"><img alt="Title abstract screening" src="https://img.shields.io/badge/Title_abstract_screening-black?style=for-the-badge&logo=&logoColor="/></a>
# </div>
# <a id="search_strategy"></a>
# <hr style="border: none; height: 1.5px; background-color: black;">
# <div align = "left"
#       <a href="#titlepage"><img alt="Previous" src="https://img.shields.io/badge/Previous-blue?style=for-the-badge"  height="60"></a>
#       <a href="#titlepage"><img alt="Top" src="https://img.shields.io/badge/Top-blue?style=for-the-badge"  height="40"></a>
#       <a href="#titlepage"><img alt="Next" src="https://img.shields.io/badge/Next-blue?style=for-the-badge"  height="40"></a>
#     <br>
#       <a href="./docs/index.md"><img alt="Docs" src="https://img.shields.io/badge/Documentation-red?style=for-the-badge"  height="60"></a>
#       <a href="./src/index.md"><img alt="Code" src="https://img.shields.io/badge/Code-red?style=for-the-badge"  height="40"></a>
#       <a href="./notebooks/index.md"><img alt="" src="https://img.shields.io/badge/App-red?style=for-the-badge"  height="40"></a>
# </div>
#
# <div align="center">
#     <h2 align="center" style="font-family:Times New Roman;font-variant: small-caps;">Search Strategy</h2></br></div>

# %% [markdown]
# Search strategies were developed for randomized controlled trials: `pm_bptb.txt`, `pm_ht.txt`, `pm_qt.txt`, `pm_plt.txt`, `pm_at.txt` and `pm_ta.txt` corresponding to PubMed search strategies for patellar, hamstring, quadriceps, peroneus longus, achilles and tibialis anterior and posterior tendones, respectively. From the protocol that was developed, extract key terms from the eligibility criteria for inclusion and exclusion of studies in order to develop a *search strategy*.
#
# The search strategies were 'translated' via regular expressions from PubMed syntax to Embase and Web of Science syntax, store them into the global environment, and save them as plain text files for importing and use as queries for search.

# %%
population = f"""(("pediatric"[tiab] OR "paediatric"[tiab] OR "adolescent"[tia) OR ("revision"[tiab] OR "repair"[tiab]))"""
acl = f"""("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab])"""
rct = f"""("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab])"""
reviews = f"""("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab])"""
study_design = " NOT ".join([rct, reviews])
outcomes = f"""("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))"""

bptb = f"""("bone-patellar tendon-bone"[tiab] OR "bone patellar tendon bone"[tiab] OR "patellar tendon"[tiab] OR "bptb"[tiab])"""
ht = f"""("hamstring"[tiab] OR "hamstring tendon"[tiab] OR "semitendinosus"[tiab] OR "gracilis"[tiab])"""
qt = f"""("quadriceps"[tiab] OR "quadriceps tendon"[tiab] OR "qt"[tiab])"""
plt = f"""("peroneus"[tiab] OR "peroneus longus"[tiab] OR "fibularis longus"[tiab])"""
at = f"""("achilles"[tiab] OR "achilles tendon"[tiab])"""
ta = f"""("tibialis"[tiab] OR "tibialis anterior"[tiab] OR "tibialis posterior"[tiab])"""

# %%
subgroups = {"bptb": bptb, 
             "ht": ht, 
             "qt": qt, 
             "plt": plt, 
             "at": at, 
             "ta": ta}

queries = {}

for x, y in subgroups.items():
    query = f"{acl} AND {y} AND ({rct} NOT {reviews}) AND {outcomes}"
    globals()[f"pm_{x}"] = query
    with open(f"./data/pm_{x}.txt", 'w') as f:
        f.write(query)

pm_queries = {
    "bptb": pm_bptb,
    "ht": pm_ht,
    "qt": pm_qt,
    "plt": pm_plt,
    "at": pm_at,
    "ta": pm_ta
}

for x, y in pm_queries.items():
    query = re.sub(r"\[(.*?)\]",":\\1", y)
    query = re.sub(r"\:tiab",":ti,ab", query)
    query = re.sub(r"\:mh","/exp", query)
    query = re.sub(r"\:pt",":it,ti,ab", query)
    query = re.sub(r'"',"'", query)
    globals()[f"em_{x}"] = query    
    with open(f"./data/em_{x}.txt", 'w') as f:
        f.write(query)

for x, y in pm_queries.items():
    query = re.sub(r'"(.*?)"\[(.*?)\]','\\2="\\1"', y)
    query = re.sub(r'tiab="(.*?)"','(TI=(\\1) OR AB=(\\1))', query)
    query = re.sub(r'mh="(.*?)"','(TMIC=(\\1))', query)
    query = re.sub(r'pt="(.*?)"','(TS=(\\1))', query)
    globals()[f"wos_{x}"] = query
    with open(f"./data/wos_{x}.txt", 'w') as f:
        f.write(query)

for x, y in pm_queries.items():
    query = re.sub(r"\[(.*?)\]",":\\1", y)
    query = re.sub(r"\:tiab",":ti,ab", query)
    query = re.sub(r"\((.*?)\:mh",r"([mh \1]", query)
    globals()[f"cochrane_{x}"] = query
    with open(f"./data/cochrane_{x}.txt", 'w') as f:
        f.write(query)

# %%
queries = [
    pm_bptb, pm_ht, pm_qt, pm_plt, pm_ta, pm_at,
    em_bptb, em_ht, em_qt, em_plt, em_ta, em_at,
    wos_bptb, wos_ht, wos_qt, wos_plt, wos_ta, wos_at,
    cochrane_bptb, cochrane_ht, cochrane_qt, cochrane_plt, cochrane_ta, cochrane_at,
]

# %%
df = pd.DataFrame({
    " ": ["P", "I", "C", "O", "S"], #"", "", ""],
    "Categories": ["Population", "Intervention", "Comparators", "Outcomes", "Study Design"], #"PubMed", "Embase", "Web of Science"],
    "Patellar": [f"NOT {population}", f"{acl}", f"{bptb}", f"{outcomes}", f"{study_design}"], #f"{pm_bptb}", f"{em_bptb}", f"{wos_bptb}"],
    "Hamstring": [f"NOT {population}", f"{acl}", f"{ht}", f"{outcomes}", f"{study_design}"], #f"{pm_ht}", f"{em_ht}", f"{wos_ht}"],
    "Quadriceps": [f"NOT {population}", f"{acl}", f"{qt}", f"{outcomes}", f"{study_design}"], #f"{pm_qt}", f"{em_qt}", f"{wos_qt}"],
    "Peroneus": [f"NOT {population}", f"{acl}", f"{plt}", f"{outcomes}", f"{study_design}"], #f"{pm_plt}", f"{em_plt}", f"{wos_plt}"],
    "Achilles": [f"NOT {population}", f"{acl}", f"{at}", f"{outcomes}", f"{study_design}"], #f"{pm_at}", f"{em_at}", f"{wos_at}"],
    "Tibialis": [f"NOT {population}", f"{acl}", f"{ta}", f"{outcomes}", f"{study_design}"], # f"{pm_ta}", f"{em_ta}", f"{wos_ta}"],
})

df.to_csv("./data/search_strategies_1.csv", encoding = "utf-8")
from IPython.display import Markdown, display
display(Markdown(df.to_markdown(index = False)))
# Out:
# |     | Categories   | Patellar                                                                                                                                                                                                                                                       | Hamstring                                                                                                                                                                                                                                                      | Quadriceps                                                                                                                                                                                                                                                     | Peroneus                                                                                                                                                                                                                                                       | Achilles                                                                                                                                                                                                                                                       | Tibialis                                                                                                                                                                                                                                                       |
# |:----|:-------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | P   | Population   | NOT (("pediatric"[tiab] OR "paediatric"[tiab] OR "adolescent"[tia) OR ("revision"[tiab] OR "repair"[tiab]))                                                                                                                                                    | NOT (("pediatric"[tiab] OR "paediatric"[tiab] OR "adolescent"[tia) OR ("revision"[tiab] OR "repair"[tiab]))                                                                                                                                                    | NOT (("pediatric"[tiab] OR "paediatric"[tiab] OR "adolescent"[tia) OR ("revision"[tiab] OR "repair"[tiab]))                                                                                                                                                    | NOT (("pediatric"[tiab] OR "paediatric"[tiab] OR "adolescent"[tia) OR ("revision"[tiab] OR "repair"[tiab]))                                                                                                                                                    | NOT (("pediatric"[tiab] OR "paediatric"[tiab] OR "adolescent"[tia) OR ("revision"[tiab] OR "repair"[tiab]))                                                                                                                                                    | NOT (("pediatric"[tiab] OR "paediatric"[tiab] OR "adolescent"[tia) OR ("revision"[tiab] OR "repair"[tiab]))                                                                                                                                                    |
# | I   | Intervention | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab])                                                                                                                   | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab])                                                                                                                   | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab])                                                                                                                   | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab])                                                                                                                   | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab])                                                                                                                   | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab])                                                                                                                   |
# | C   | Comparators  | ("bone-patellar tendon-bone"[tiab] OR "bone patellar tendon bone"[tiab] OR "patellar tendon"[tiab] OR "bptb"[tiab])                                                                                                                                            | ("hamstring"[tiab] OR "hamstring tendon"[tiab] OR "semitendinosus"[tiab] OR "gracilis"[tiab])                                                                                                                                                                  | ("quadriceps"[tiab] OR "quadriceps tendon"[tiab] OR "qt"[tiab])                                                                                                                                                                                                | ("peroneus"[tiab] OR "peroneus longus"[tiab] OR "fibularis longus"[tiab])                                                                                                                                                                                      | ("achilles"[tiab] OR "achilles tendon"[tiab])                                                                                                                                                                                                                  | ("tibialis"[tiab] OR "tibialis anterior"[tiab] OR "tibialis posterior"[tiab])                                                                                                                                                                                  |
# | O   | Outcomes     | ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                | ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                | ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                | ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                | ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                | ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                |
# | S   | Study Design | ("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab]) | ("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab]) | ("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab]) | ("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab]) | ("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab]) | ("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab]) |

# %%
pubmed = [f"{pm_bptb}", f"{pm_ht}", f"{pm_qt}", f"{pm_plt}", f"{pm_at}", f"{pm_ta}"]
embase = [f"{em_bptb}", f"{em_ht}", f"{em_qt}", f"{em_plt}",f"{em_at}", f"{em_ta}"]
wos = [f"{wos_bptb}", f"{wos_ht}", f"{wos_qt}", f"{wos_plt}", f"{wos_at}", f"{wos_ta}"]
cochrane = [f"{cochrane_bptb}", f"{cochrane_ht}", f"{cochrane_qt}", f"{cochrane_plt}", f"{cochrane_at}", f"{cochrane_ta}"]

df = pd.DataFrame({
    " ": ["BPTB", "HT", "QT", "PLT", "AT", "TA"],
    "Subgroup": ["Patellar", "Hamstring", "Quadriceps", "Peroneus", "Achilles", "Tibialis"],
    "PubMed": pubmed,
    "Embase": embase,
    "Web of Science": wos,
    "Cochrane Library": cochrane,
})

df.to_csv("./data/search_strategies_2.csv", encoding = "utf-8", index = False)
from IPython.display import Markdown, display
markdown_table = df.to_markdown(index = False)
display(Markdown(markdown_table))
# Out:
# |      | Subgroup   | PubMed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        | Embase                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            | Web of Science                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | Cochrane Library                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |:-----|:-----------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | BPTB | Patellar   | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab]) AND ("bone-patellar tendon-bone"[tiab] OR "bone patellar tendon bone"[tiab] OR "patellar tendon"[tiab] OR "bptb"[tiab]) AND (("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab])) AND ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab])) | ('anterior cruciate ligament'/exp OR 'anterior cruciate ligament':ti,ab OR 'anterior cruciate ligament reconstruction':ti,ab OR 'acl':ti,ab) AND ('bone-patellar tendon-bone':ti,ab OR 'bone patellar tendon bone':ti,ab OR 'patellar tendon':ti,ab OR 'bptb':ti,ab) AND (('randomized controlled trial':it,ti,ab OR 'randomized controlled trial':ti,ab OR 'randomised controlled trial':ti,ab) NOT ('review':it,ti,ab OR 'review':ti,ab OR 'systematic review':it,ti,ab OR 'systematic review':ti,ab OR 'meta-analysis':it,ti,ab OR 'meta-analysis':ti,ab)) AND ('ikdc':ti,ab OR 'lysholm':ti,ab OR 'tegner':ti,ab OR (('instrumental laxity':ti,ab OR 'kt-1000':ti,ab OR 'kt-2000':ti,ab OR 'rolimeter':ti,ab) OR 'pivot shift':ti,ab OR 'lachman':ti,ab) OR ('graft failure':ti,ab OR 'graft rupture':ti,ab)) | ((TMIC=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament) OR AB=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament reconstruction) OR AB=(anterior cruciate ligament reconstruction)) OR (TI=(acl) OR AB=(acl))) AND ((TI=(bone-patellar tendon-bone) OR AB=(bone-patellar tendon-bone)) OR (TI=(bone patellar tendon bone) OR AB=(bone patellar tendon bone)) OR (TI=(patellar tendon) OR AB=(patellar tendon)) OR (TI=(bptb) OR AB=(bptb))) AND (((TS=(randomized controlled trial)) OR (TI=(randomized controlled trial) OR AB=(randomized controlled trial)) OR (TI=(randomised controlled trial) OR AB=(randomised controlled trial))) NOT ((TS=(review)) OR (TI=(review) OR AB=(review)) OR (TS=(systematic review)) OR (TI=(systematic review) OR AB=(systematic review)) OR (TS=(meta-analysis)) OR (TI=(meta-analysis) OR AB=(meta-analysis)))) AND ((TI=(ikdc) OR AB=(ikdc)) OR (TI=(lysholm) OR AB=(lysholm)) OR (TI=(tegner) OR AB=(tegner)) OR (((TI=(instrumental laxity) OR AB=(instrumental laxity)) OR (TI=(kt-1000) OR AB=(kt-1000)) OR (TI=(kt-2000) OR AB=(kt-2000)) OR (TI=(rolimeter) OR AB=(rolimeter))) OR (TI=(pivot shift) OR AB=(pivot shift)) OR (TI=(lachman) OR AB=(lachman))) OR ((TI=(graft failure) OR AB=(graft failure)) OR (TI=(graft rupture) OR AB=(graft rupture)))) | ([mh "anterior cruciate ligament"] OR "anterior cruciate ligament":ti,ab OR "anterior cruciate ligament reconstruction":ti,ab OR "acl":ti,ab) AND ("bone-patellar tendon-bone":ti,ab OR "bone patellar tendon bone":ti,ab OR "patellar tendon":ti,ab OR "bptb":ti,ab) AND (("randomized controlled trial":pt OR "randomized controlled trial":ti,ab OR "randomised controlled trial":ti,ab) NOT ("review":pt OR "review":ti,ab OR "systematic review":pt OR "systematic review":ti,ab OR "meta-analysis":pt OR "meta-analysis":ti,ab)) AND ("ikdc":ti,ab OR "lysholm":ti,ab OR "tegner":ti,ab OR (("instrumental laxity":ti,ab OR "kt-1000":ti,ab OR "kt-2000":ti,ab OR "rolimeter":ti,ab) OR "pivot shift":ti,ab OR "lachman":ti,ab) OR ("graft failure":ti,ab OR "graft rupture":ti,ab)) |
# | HT   | Hamstring  | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab]) AND ("hamstring"[tiab] OR "hamstring tendon"[tiab] OR "semitendinosus"[tiab] OR "gracilis"[tiab]) AND (("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab])) AND ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                       | ('anterior cruciate ligament'/exp OR 'anterior cruciate ligament':ti,ab OR 'anterior cruciate ligament reconstruction':ti,ab OR 'acl':ti,ab) AND ('hamstring':ti,ab OR 'hamstring tendon':ti,ab OR 'semitendinosus':ti,ab OR 'gracilis':ti,ab) AND (('randomized controlled trial':it,ti,ab OR 'randomized controlled trial':ti,ab OR 'randomised controlled trial':ti,ab) NOT ('review':it,ti,ab OR 'review':ti,ab OR 'systematic review':it,ti,ab OR 'systematic review':ti,ab OR 'meta-analysis':it,ti,ab OR 'meta-analysis':ti,ab)) AND ('ikdc':ti,ab OR 'lysholm':ti,ab OR 'tegner':ti,ab OR (('instrumental laxity':ti,ab OR 'kt-1000':ti,ab OR 'kt-2000':ti,ab OR 'rolimeter':ti,ab) OR 'pivot shift':ti,ab OR 'lachman':ti,ab) OR ('graft failure':ti,ab OR 'graft rupture':ti,ab))                       | ((TMIC=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament) OR AB=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament reconstruction) OR AB=(anterior cruciate ligament reconstruction)) OR (TI=(acl) OR AB=(acl))) AND ((TI=(hamstring) OR AB=(hamstring)) OR (TI=(hamstring tendon) OR AB=(hamstring tendon)) OR (TI=(semitendinosus) OR AB=(semitendinosus)) OR (TI=(gracilis) OR AB=(gracilis))) AND (((TS=(randomized controlled trial)) OR (TI=(randomized controlled trial) OR AB=(randomized controlled trial)) OR (TI=(randomised controlled trial) OR AB=(randomised controlled trial))) NOT ((TS=(review)) OR (TI=(review) OR AB=(review)) OR (TS=(systematic review)) OR (TI=(systematic review) OR AB=(systematic review)) OR (TS=(meta-analysis)) OR (TI=(meta-analysis) OR AB=(meta-analysis)))) AND ((TI=(ikdc) OR AB=(ikdc)) OR (TI=(lysholm) OR AB=(lysholm)) OR (TI=(tegner) OR AB=(tegner)) OR (((TI=(instrumental laxity) OR AB=(instrumental laxity)) OR (TI=(kt-1000) OR AB=(kt-1000)) OR (TI=(kt-2000) OR AB=(kt-2000)) OR (TI=(rolimeter) OR AB=(rolimeter))) OR (TI=(pivot shift) OR AB=(pivot shift)) OR (TI=(lachman) OR AB=(lachman))) OR ((TI=(graft failure) OR AB=(graft failure)) OR (TI=(graft rupture) OR AB=(graft rupture))))                                             | ([mh "anterior cruciate ligament"] OR "anterior cruciate ligament":ti,ab OR "anterior cruciate ligament reconstruction":ti,ab OR "acl":ti,ab) AND ("hamstring":ti,ab OR "hamstring tendon":ti,ab OR "semitendinosus":ti,ab OR "gracilis":ti,ab) AND (("randomized controlled trial":pt OR "randomized controlled trial":ti,ab OR "randomised controlled trial":ti,ab) NOT ("review":pt OR "review":ti,ab OR "systematic review":pt OR "systematic review":ti,ab OR "meta-analysis":pt OR "meta-analysis":ti,ab)) AND ("ikdc":ti,ab OR "lysholm":ti,ab OR "tegner":ti,ab OR (("instrumental laxity":ti,ab OR "kt-1000":ti,ab OR "kt-2000":ti,ab OR "rolimeter":ti,ab) OR "pivot shift":ti,ab OR "lachman":ti,ab) OR ("graft failure":ti,ab OR "graft rupture":ti,ab))                       |
# | QT   | Quadriceps | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab]) AND ("quadriceps"[tiab] OR "quadriceps tendon"[tiab] OR "qt"[tiab]) AND (("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab])) AND ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                                                     | ('anterior cruciate ligament'/exp OR 'anterior cruciate ligament':ti,ab OR 'anterior cruciate ligament reconstruction':ti,ab OR 'acl':ti,ab) AND ('quadriceps':ti,ab OR 'quadriceps tendon':ti,ab OR 'qt':ti,ab) AND (('randomized controlled trial':it,ti,ab OR 'randomized controlled trial':ti,ab OR 'randomised controlled trial':ti,ab) NOT ('review':it,ti,ab OR 'review':ti,ab OR 'systematic review':it,ti,ab OR 'systematic review':ti,ab OR 'meta-analysis':it,ti,ab OR 'meta-analysis':ti,ab)) AND ('ikdc':ti,ab OR 'lysholm':ti,ab OR 'tegner':ti,ab OR (('instrumental laxity':ti,ab OR 'kt-1000':ti,ab OR 'kt-2000':ti,ab OR 'rolimeter':ti,ab) OR 'pivot shift':ti,ab OR 'lachman':ti,ab) OR ('graft failure':ti,ab OR 'graft rupture':ti,ab))                                                     | ((TMIC=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament) OR AB=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament reconstruction) OR AB=(anterior cruciate ligament reconstruction)) OR (TI=(acl) OR AB=(acl))) AND ((TI=(quadriceps) OR AB=(quadriceps)) OR (TI=(quadriceps tendon) OR AB=(quadriceps tendon)) OR (TI=(qt) OR AB=(qt))) AND (((TS=(randomized controlled trial)) OR (TI=(randomized controlled trial) OR AB=(randomized controlled trial)) OR (TI=(randomised controlled trial) OR AB=(randomised controlled trial))) NOT ((TS=(review)) OR (TI=(review) OR AB=(review)) OR (TS=(systematic review)) OR (TI=(systematic review) OR AB=(systematic review)) OR (TS=(meta-analysis)) OR (TI=(meta-analysis) OR AB=(meta-analysis)))) AND ((TI=(ikdc) OR AB=(ikdc)) OR (TI=(lysholm) OR AB=(lysholm)) OR (TI=(tegner) OR AB=(tegner)) OR (((TI=(instrumental laxity) OR AB=(instrumental laxity)) OR (TI=(kt-1000) OR AB=(kt-1000)) OR (TI=(kt-2000) OR AB=(kt-2000)) OR (TI=(rolimeter) OR AB=(rolimeter))) OR (TI=(pivot shift) OR AB=(pivot shift)) OR (TI=(lachman) OR AB=(lachman))) OR ((TI=(graft failure) OR AB=(graft failure)) OR (TI=(graft rupture) OR AB=(graft rupture))))                                                                                                     | ([mh "anterior cruciate ligament"] OR "anterior cruciate ligament":ti,ab OR "anterior cruciate ligament reconstruction":ti,ab OR "acl":ti,ab) AND ("quadriceps":ti,ab OR "quadriceps tendon":ti,ab OR "qt":ti,ab) AND (("randomized controlled trial":pt OR "randomized controlled trial":ti,ab OR "randomised controlled trial":ti,ab) NOT ("review":pt OR "review":ti,ab OR "systematic review":pt OR "systematic review":ti,ab OR "meta-analysis":pt OR "meta-analysis":ti,ab)) AND ("ikdc":ti,ab OR "lysholm":ti,ab OR "tegner":ti,ab OR (("instrumental laxity":ti,ab OR "kt-1000":ti,ab OR "kt-2000":ti,ab OR "rolimeter":ti,ab) OR "pivot shift":ti,ab OR "lachman":ti,ab) OR ("graft failure":ti,ab OR "graft rupture":ti,ab))                                                     |
# | PLT  | Peroneus   | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab]) AND ("peroneus"[tiab] OR "peroneus longus"[tiab] OR "fibularis longus"[tiab]) AND (("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab])) AND ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                                           | ('anterior cruciate ligament'/exp OR 'anterior cruciate ligament':ti,ab OR 'anterior cruciate ligament reconstruction':ti,ab OR 'acl':ti,ab) AND ('peroneus':ti,ab OR 'peroneus longus':ti,ab OR 'fibularis longus':ti,ab) AND (('randomized controlled trial':it,ti,ab OR 'randomized controlled trial':ti,ab OR 'randomised controlled trial':ti,ab) NOT ('review':it,ti,ab OR 'review':ti,ab OR 'systematic review':it,ti,ab OR 'systematic review':ti,ab OR 'meta-analysis':it,ti,ab OR 'meta-analysis':ti,ab)) AND ('ikdc':ti,ab OR 'lysholm':ti,ab OR 'tegner':ti,ab OR (('instrumental laxity':ti,ab OR 'kt-1000':ti,ab OR 'kt-2000':ti,ab OR 'rolimeter':ti,ab) OR 'pivot shift':ti,ab OR 'lachman':ti,ab) OR ('graft failure':ti,ab OR 'graft rupture':ti,ab))                                           | ((TMIC=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament) OR AB=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament reconstruction) OR AB=(anterior cruciate ligament reconstruction)) OR (TI=(acl) OR AB=(acl))) AND ((TI=(peroneus) OR AB=(peroneus)) OR (TI=(peroneus longus) OR AB=(peroneus longus)) OR (TI=(fibularis longus) OR AB=(fibularis longus))) AND (((TS=(randomized controlled trial)) OR (TI=(randomized controlled trial) OR AB=(randomized controlled trial)) OR (TI=(randomised controlled trial) OR AB=(randomised controlled trial))) NOT ((TS=(review)) OR (TI=(review) OR AB=(review)) OR (TS=(systematic review)) OR (TI=(systematic review) OR AB=(systematic review)) OR (TS=(meta-analysis)) OR (TI=(meta-analysis) OR AB=(meta-analysis)))) AND ((TI=(ikdc) OR AB=(ikdc)) OR (TI=(lysholm) OR AB=(lysholm)) OR (TI=(tegner) OR AB=(tegner)) OR (((TI=(instrumental laxity) OR AB=(instrumental laxity)) OR (TI=(kt-1000) OR AB=(kt-1000)) OR (TI=(kt-2000) OR AB=(kt-2000)) OR (TI=(rolimeter) OR AB=(rolimeter))) OR (TI=(pivot shift) OR AB=(pivot shift)) OR (TI=(lachman) OR AB=(lachman))) OR ((TI=(graft failure) OR AB=(graft failure)) OR (TI=(graft rupture) OR AB=(graft rupture))))                                                                                 | ([mh "anterior cruciate ligament"] OR "anterior cruciate ligament":ti,ab OR "anterior cruciate ligament reconstruction":ti,ab OR "acl":ti,ab) AND ("peroneus":ti,ab OR "peroneus longus":ti,ab OR "fibularis longus":ti,ab) AND (("randomized controlled trial":pt OR "randomized controlled trial":ti,ab OR "randomised controlled trial":ti,ab) NOT ("review":pt OR "review":ti,ab OR "systematic review":pt OR "systematic review":ti,ab OR "meta-analysis":pt OR "meta-analysis":ti,ab)) AND ("ikdc":ti,ab OR "lysholm":ti,ab OR "tegner":ti,ab OR (("instrumental laxity":ti,ab OR "kt-1000":ti,ab OR "kt-2000":ti,ab OR "rolimeter":ti,ab) OR "pivot shift":ti,ab OR "lachman":ti,ab) OR ("graft failure":ti,ab OR "graft rupture":ti,ab))                                           |
# | AT   | Achilles   | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab]) AND ("achilles"[tiab] OR "achilles tendon"[tiab]) AND (("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab])) AND ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                                                                       | ('anterior cruciate ligament'/exp OR 'anterior cruciate ligament':ti,ab OR 'anterior cruciate ligament reconstruction':ti,ab OR 'acl':ti,ab) AND ('achilles':ti,ab OR 'achilles tendon':ti,ab) AND (('randomized controlled trial':it,ti,ab OR 'randomized controlled trial':ti,ab OR 'randomised controlled trial':ti,ab) NOT ('review':it,ti,ab OR 'review':ti,ab OR 'systematic review':it,ti,ab OR 'systematic review':ti,ab OR 'meta-analysis':it,ti,ab OR 'meta-analysis':ti,ab)) AND ('ikdc':ti,ab OR 'lysholm':ti,ab OR 'tegner':ti,ab OR (('instrumental laxity':ti,ab OR 'kt-1000':ti,ab OR 'kt-2000':ti,ab OR 'rolimeter':ti,ab) OR 'pivot shift':ti,ab OR 'lachman':ti,ab) OR ('graft failure':ti,ab OR 'graft rupture':ti,ab))                                                                       | ((TMIC=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament) OR AB=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament reconstruction) OR AB=(anterior cruciate ligament reconstruction)) OR (TI=(acl) OR AB=(acl))) AND ((TI=(achilles) OR AB=(achilles)) OR (TI=(achilles tendon) OR AB=(achilles tendon))) AND (((TS=(randomized controlled trial)) OR (TI=(randomized controlled trial) OR AB=(randomized controlled trial)) OR (TI=(randomised controlled trial) OR AB=(randomised controlled trial))) NOT ((TS=(review)) OR (TI=(review) OR AB=(review)) OR (TS=(systematic review)) OR (TI=(systematic review) OR AB=(systematic review)) OR (TS=(meta-analysis)) OR (TI=(meta-analysis) OR AB=(meta-analysis)))) AND ((TI=(ikdc) OR AB=(ikdc)) OR (TI=(lysholm) OR AB=(lysholm)) OR (TI=(tegner) OR AB=(tegner)) OR (((TI=(instrumental laxity) OR AB=(instrumental laxity)) OR (TI=(kt-1000) OR AB=(kt-1000)) OR (TI=(kt-2000) OR AB=(kt-2000)) OR (TI=(rolimeter) OR AB=(rolimeter))) OR (TI=(pivot shift) OR AB=(pivot shift)) OR (TI=(lachman) OR AB=(lachman))) OR ((TI=(graft failure) OR AB=(graft failure)) OR (TI=(graft rupture) OR AB=(graft rupture))))                                                                                                                                     | ([mh "anterior cruciate ligament"] OR "anterior cruciate ligament":ti,ab OR "anterior cruciate ligament reconstruction":ti,ab OR "acl":ti,ab) AND ("achilles":ti,ab OR "achilles tendon":ti,ab) AND (("randomized controlled trial":pt OR "randomized controlled trial":ti,ab OR "randomised controlled trial":ti,ab) NOT ("review":pt OR "review":ti,ab OR "systematic review":pt OR "systematic review":ti,ab OR "meta-analysis":pt OR "meta-analysis":ti,ab)) AND ("ikdc":ti,ab OR "lysholm":ti,ab OR "tegner":ti,ab OR (("instrumental laxity":ti,ab OR "kt-1000":ti,ab OR "kt-2000":ti,ab OR "rolimeter":ti,ab) OR "pivot shift":ti,ab OR "lachman":ti,ab) OR ("graft failure":ti,ab OR "graft rupture":ti,ab))                                                                       |
# | TA   | Tibialis   | ("anterior cruciate ligament"[mh] OR "anterior cruciate ligament"[tiab] OR "anterior cruciate ligament reconstruction"[tiab] OR "acl"[tiab]) AND ("tibialis"[tiab] OR "tibialis anterior"[tiab] OR "tibialis posterior"[tiab]) AND (("randomized controlled trial"[pt] OR "randomized controlled trial"[tiab] OR "randomised controlled trial"[tiab]) NOT ("review"[pt] OR "review"[tiab] OR "systematic review"[pt] OR "systematic review"[tiab] OR "meta-analysis"[pt] OR "meta-analysis"[tiab])) AND ("ikdc"[tiab] OR "lysholm"[tiab] OR "tegner"[tiab] OR (("instrumental laxity"[tiab] OR "kt-1000"[tiab] OR "kt-2000"[tiab] OR "rolimeter"[tiab]) OR "pivot shift"[tiab] OR "lachman"[tiab]) OR ("graft failure"[tiab] OR "graft rupture"[tiab]))                                       | ('anterior cruciate ligament'/exp OR 'anterior cruciate ligament':ti,ab OR 'anterior cruciate ligament reconstruction':ti,ab OR 'acl':ti,ab) AND ('tibialis':ti,ab OR 'tibialis anterior':ti,ab OR 'tibialis posterior':ti,ab) AND (('randomized controlled trial':it,ti,ab OR 'randomized controlled trial':ti,ab OR 'randomised controlled trial':ti,ab) NOT ('review':it,ti,ab OR 'review':ti,ab OR 'systematic review':it,ti,ab OR 'systematic review':ti,ab OR 'meta-analysis':it,ti,ab OR 'meta-analysis':ti,ab)) AND ('ikdc':ti,ab OR 'lysholm':ti,ab OR 'tegner':ti,ab OR (('instrumental laxity':ti,ab OR 'kt-1000':ti,ab OR 'kt-2000':ti,ab OR 'rolimeter':ti,ab) OR 'pivot shift':ti,ab OR 'lachman':ti,ab) OR ('graft failure':ti,ab OR 'graft rupture':ti,ab))                                       | ((TMIC=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament) OR AB=(anterior cruciate ligament)) OR (TI=(anterior cruciate ligament reconstruction) OR AB=(anterior cruciate ligament reconstruction)) OR (TI=(acl) OR AB=(acl))) AND ((TI=(tibialis) OR AB=(tibialis)) OR (TI=(tibialis anterior) OR AB=(tibialis anterior)) OR (TI=(tibialis posterior) OR AB=(tibialis posterior))) AND (((TS=(randomized controlled trial)) OR (TI=(randomized controlled trial) OR AB=(randomized controlled trial)) OR (TI=(randomised controlled trial) OR AB=(randomised controlled trial))) NOT ((TS=(review)) OR (TI=(review) OR AB=(review)) OR (TS=(systematic review)) OR (TI=(systematic review) OR AB=(systematic review)) OR (TS=(meta-analysis)) OR (TI=(meta-analysis) OR AB=(meta-analysis)))) AND ((TI=(ikdc) OR AB=(ikdc)) OR (TI=(lysholm) OR AB=(lysholm)) OR (TI=(tegner) OR AB=(tegner)) OR (((TI=(instrumental laxity) OR AB=(instrumental laxity)) OR (TI=(kt-1000) OR AB=(kt-1000)) OR (TI=(kt-2000) OR AB=(kt-2000)) OR (TI=(rolimeter) OR AB=(rolimeter))) OR (TI=(pivot shift) OR AB=(pivot shift)) OR (TI=(lachman) OR AB=(lachman))) OR ((TI=(graft failure) OR AB=(graft failure)) OR (TI=(graft rupture) OR AB=(graft rupture))))                                                                         | ([mh "anterior cruciate ligament"] OR "anterior cruciate ligament":ti,ab OR "anterior cruciate ligament reconstruction":ti,ab OR "acl":ti,ab) AND ("tibialis":ti,ab OR "tibialis anterior":ti,ab OR "tibialis posterior":ti,ab) AND (("randomized controlled trial":pt OR "randomized controlled trial":ti,ab OR "randomised controlled trial":ti,ab) NOT ("review":pt OR "review":ti,ab OR "systematic review":pt OR "systematic review":ti,ab OR "meta-analysis":pt OR "meta-analysis":ti,ab)) AND ("ikdc":ti,ab OR "lysholm":ti,ab OR "tegner":ti,ab OR (("instrumental laxity":ti,ab OR "kt-1000":ti,ab OR "kt-2000":ti,ab OR "rolimeter":ti,ab) OR "pivot shift":ti,ab OR "lachman":ti,ab) OR ("graft failure":ti,ab OR "graft rupture":ti,ab))                                       |

# %% [markdown]
# <a id="search"></a>
# <div align = "center">
# <a href="#protocol"><img alt="Protocol" src="https://img.shields.io/badge/Protocol-black?style=for-the-badge" /></a>
# <a href="#search_strategy"><img alt="Search Strategy" src="https://img.shields.io/badge/Search_Strategy-black?style=for-the-badge" /></a>
# <a href="#search"><img alt="Search" src="https://img.shields.io/badge/Search-black?style=for-the-badge" /></a>
# <a href="#deduplication"><img alt="Deduplication" src="https://img.shields.io/badge/Deduplication-black?style=for-the-badge" /></a>
# <a href="#screening"><img alt="Screening" src="https://img.shields.io/badge/Screening-black?style=for-the-badge" /></a>
# <a href="#title_abstract_screening"><img alt="Title abstract screening" src="https://img.shields.io/badge/Title_abstract_screening-black?style=for-the-badge&logo=&logoColor="/></a>
# </div>
#
# <hr style="border: none; height: 1.5px; background-color: black;">
# <div align = "left"
#       <a href="#titlepage"><img alt="Previous" src="https://img.shields.io/badge/Previous-blue?style=for-the-badge"  height="60"></a>
#       <a href="#titlepage"><img alt="Top" src="https://img.shields.io/badge/Top-blue?style=for-the-badge"  height="40"></a>
#       <a href="#titlepage"><img alt="Next" src="https://img.shields.io/badge/Next-blue?style=for-the-badge"  height="40"></a>
#     <br>
#       <a href="./docs/index.md"><img alt="Docs" src="https://img.shields.io/badge/Documentation-red?style=for-the-badge"  height="60"></a>
#       <a href="./src/index.md"><img alt="Code" src="https://img.shields.io/badge/Code-red?style=for-the-badge"  height="40"></a>
#       <a href="./notebooks/index.md"><img alt="" src="https://img.shields.io/badge/App-red?style=for-the-badge"  height="40"></a>
# </div>
#
# <div align="center">
# <h2 align="center" style="font-family:Times New Roman;font-variant:small-caps;">Search</h2>

# %% [markdown]
# A script to either create a search strategy using the terms, field tags, and Boolean operators and save them as plain text files or load already written and saved plain text files for import into the API search scripts. This uses the search strategies (e.g., `pm_bptb.txt`, search strategy in plain text written in PubMed syntax for bone-patellar tendon-bone (BPTB) subgroup search) and pulls data from PubMed to output PMIDs (`pmid_pm_bptb.txt`) and search results in XML (`pm_bptb.xml`) and parses this into CSV files (`pm_bptb.csv`).

# %%
from src import search

# %% [markdown]
# ```mermaid
# ---
# config:
#   theme: light
#   curve: stepBefore
# ---
#
# flowchart TD
# A0["PubMed"]
# A1["pm_bptb"]
# B1["pm_ht"]
# C1["pm_qt"]
# D1["pm_plt"]
# E1["pm_at"]
# F1["pm_ta"]
#
# A2["em_bptb"]
# B2["em_ht"]
# C2["em_qt"]
# D2["em_plt"]
# E2["em_at"]
# F2["em_ta"]
#
# A3["wos_bptb"]
# B3["wos_ht"]
# C3["wos_qt"]
# D3["wos_plt"]
# E3["wos_at"]
# F3["wos_ta"]
#
# A4["cochrane_bptb"]
# B4["cochrane_ht"]
# C4["cochrane_qt"]
# D4["cochrane_plt"]
# E4["cochrane_at"]
# F4["cochrane_ta"]
#
# G["pubmed"]
# H["embase"]
# I["wos"]
# J["cochrane"]
#
# A1 & B1 & C1 & D1 & E1 & F1 --> G
# A2 & B2 & C2 & D2 & E2 & F2 --> H
# A3 & B3 & C3 & D3 & E3 & F3 --> I
# A4 & B4 & C4 & D4 & E4 & F4 --> J
#
# G & H & I & J --> K["records"]
#
# click A1 "https://github/"
# ```

# %% [markdown]
# **Import the raw datasets exported from database searches**

# %%
dfs = [
    "pm_bptb",
    "pm_ht",
    "pm_qt",
    "pm_plt",
    "pm_at",
    "pm_ta",
    "em_bptb",
    "em_ht",
    "em_qt",
    "em_plt",
    "em_at",
    "em_ta",
    "wos_bptb",
    "wos_ht",
    "wos_qt",
    "wos_plt",
    "wos_at",
    "wos_ta",
]

url = "https://raw.githubusercontent.com/d-wkim/d-wkim/refs/heads/main/data/"

for filename in dfs:
    url = u
    df = pd.read_csv(f"{url}/{filename}.csv", encoding = "utf-8")
    globals()[f"{filename}"] = df
    print(df)
# Out:
#      Unnamed: 0      pmid       PubDate     EPubDate                 Source  \
# 0             0  41536854      2026 Mar  2025 Dec 20  Lancet Reg Health Eur
# 1             1  39886263      2025 Jan  2025 Jan 29    Orthop J Sports Med
# 2             2  39221503      2024 Sep   2024 Sep 2        Am J Sports Med
# 3             3  38021297      2023 Nov  2023 Nov 17    Orthop J Sports Med
# 4             4  37893482    2023 Oct 3   2023 Oct 3      Medicina (Kaunas)
# ..          ...       ...           ...          ...                    ...
# 134         134   8403647      1993 Oct          NaN  Clin Orthop Relat Res
# 135         135   1558237  1992 Mar-Apr          NaN        Am J Sports Med
# 136         136   2009118          1991          NaN            Arthroscopy
# 137         137   2285086  1990 Nov-Dec          NaN        Am J Sports Med
# 138         138   2323135      1990 May          NaN  Clin Orthop Relat Res
#
#                                             AuthorList      LastAuthor  \
# 0    ['Sonnery-Cottet B', 'Carrozzo A', 'Poilvache ...       Saithna A
# 1    ['Lucidi GA', 'Agostinone P', 'Di Paolo S', 'D...    Zaffagnini S
# 2    ['Popovic M', 'Myhre JR', 'Holen JIH', 'Gifsta...      Drogset JO
# 3    ['Anz AW', 'Jordan SE', 'Ostrander RV 3rd', 'B...      Andrews JR
# 4    ['Obradović M', 'Ninković S', 'Gvozdenović N',...         Dulić O
# ..                                                 ...             ...
# 134         ['Engström B', 'Wredmark T', 'Westblad P']      Westblad P
# 135            ['Rosen MA', 'Jackson DW', 'Atwell EA']       Atwell EA
# 136   ['Richmond JC', 'Gladstone J', 'MacGillivray J']  MacGillivray J
# 137  ['Engebretsen L', 'Benum P', 'Fasting O', 'Møl...        Strand T
# 138                                         ['Kohn D']          Kohn D
#
#                                                  Title Volume Issue  ...  \
# 0    Anterior cruciate ligament reconstruction comb...     62   NaN  ...
# 1    Long-term Outcomes After Anterior Cruciate Lig...     13     1  ...
# 2    Reduced Knee Flexion Strength 18 Years After A...     52    11  ...
# 3    Augmentation of ACL Autograft Reconstruction W...     11    11  ...
# 4    Tubularization of Bone-Tendon-Bone Grafts: Eff...     59    10  ...
# ..                                                 ...    ...   ...  ...
# 134  Patellar tendon or Leeds-Keio graft in the sur...    NaN   295  ...
# 135  The efficacy of continuous passive motion in t...     20     2  ...
# 136  Continuous passive motion after arthroscopical...      7     1  ...
# 137  A prospective, randomized study of three surgi...     18     6  ...
# 138  Arthroscopic evaluation of anterior cruciate l...    NaN   254  ...
#
#                               DOI  \
# 0    10.1016/j.lanepe.2025.101561
# 1       10.1177/23259671241302348
# 2       10.1177/03635465241271524
# 3       10.1177/23259671231210035
# 4        10.3390/medicina59101764
# ..                            ...
# 134                           NaN
# 135    10.1177/036354659202000205
# 136  10.1016/0749-8063(91)90076-a
# 137    10.1177/036354659001800605
# 138                           NaN
#
#                                                History  \
# 0    ['2025/07/18 00:00', '2025/10/31 00:00', '2025...
# 1    ['2024/05/22 00:00', '2024/05/23 00:00', '2025...
# 2    ['2024/09/14 15:46', '2024/09/02 08:45', '2024...
# 3    ['2023/05/22 00:00', '2023/06/06 00:00', '2023...
# 4    ['2023/08/31 00:00', '2023/09/24 00:00', '2023...
# ..                                                 ...
# 134  ['1993/10/01 00:00', '1993/10/01 00:01', '1993...
# 135  ['1992/03/01 00:00', '1992/03/01 00:01', '1992...
# 136  ['1991/01/01 00:00', '1991/01/01 00:01', '1991...
# 137  ['1990/11/01 00:00', '1990/11/01 00:01', '1990...
# 138  ['1990/05/01 00:00', '1990/05/01 00:01', '1990...
#
#                                             References HasAbstract  \
# 0                                                   []           1
# 1    ['Orthop J Sports Med. 2025 Sep 30;13(9):23259...           1
# 2                                                   []           1
# 3                                                   []           1
# 4                                                   []           1
# ..                                                 ...         ...
# 134                                                 []           1
# 135                                                 []           1
# 136                      ['Arthroscopy 1991;7(2):256']           1
# 137                                                 []           1
# 138                                                 []           1
#
#     PmcRefCount                                    FullJournalName  \
# 0            42                 The Lancet regional health. Europe
# 1            36             Orthopaedic journal of sports medicine
# 2             0            The American journal of sports medicine
# 3            36             Orthopaedic journal of sports medicine
# 4            48                       Medicina (Kaunas, Lithuania)
# ..          ...                                                ...
# 134           0         Clinical orthopaedics and related research
# 135           0            The American journal of sports medicine
# 136           0  Arthroscopy : the journal of arthroscopic & re...
# 137           0            The American journal of sports medicine
# 138           0         Clinical orthopaedics and related research
#
#                            ELocationID                                 SO  \
# 0    doi: 10.1016/j.lanepe.2025.101561                 2026 Mar;62:101561
# 1       doi: 10.1177/23259671241302348   2025 Jan;13(1):23259671241302348
# 2       doi: 10.1177/03635465241271524          2024 Sep;52(11):2750-2757
# 3       doi: 10.1177/23259671231210035  2023 Nov;11(11):23259671231210035
# 4        doi: 10.3390/medicina59101764                  2023 Oct 3;59(10)
# ..                                 ...                                ...
# 134                                NaN               1993 Oct;(295):190-7
# 135                                NaN           1992 Mar-Apr;20(2):122-7
# 136                                NaN                    1991;7(1):39-44
# 137                                NaN          1990 Nov-Dec;18(6):585-90
# 138                                NaN               1990 May;(254):220-4
#
#                                               abstract  year
# 0    BACKGROUND: Anterior Cruciate Ligament (ACL) r...  2026
# 1    BACKGROUND: In recent years, lateral extra-art...  2025
# 2    BACKGROUND: Bone-patellar tendon-bone (BPTB) a...  2024
# 3    BACKGROUND: It is theorized that the lack of a...  2023
# 4    Background and Objectives: The study addresses...  2023
# ..                                                 ...   ...
# 134  In a prospective randomized study, 60 patients...  1993
# 135  Seventy-five patients undergoing arthroscopica...  1992
# 136  The use of continuous passive motion (CPM) fol...  1991
# 137  Treatment of ACL tears is controversial. Recen...  1990
# 138  In a prospective study, follow-up arthroscopy ...  1990
#
# [139 rows x 29 columns]
#      Unnamed: 0      pmid       PubDate     EPubDate  \
# 0             0  41827078   2026 Mar 13  2026 Mar 13
# 1             1  41740851   2026 Feb 23  2026 Feb 23
# 2             2  41536854      2026 Mar  2025 Dec 20
# 3             3  41083992   2025 Oct 13  2025 Oct 13
# 4             4  41018256      2025 Jul  2025 Sep 24
# ..          ...       ...           ...          ...
# 217         217  10210074      1999 Mar          NaN
# 218         218   9006702  1997 Jan-Feb          NaN
# 219         219   8666597      1996 Jun          NaN
# 220         220   8600739  1995 Nov-Dec          NaN
# 221         221   7899626          1994          NaN
#
#                                     Source  \
# 0                        J Orthop Surg Res
# 1                                 J ISAKOS
# 2                    Lancet Reg Health Eur
# 3                 BMC Musculoskelet Disord
# 4                             J Exp Orthop
# ..                                     ...
# 217                            Arthroscopy
# 218                        Am J Sports Med
# 219                   J Bone Joint Surg Am
# 220                        Am J Sports Med
# 221  Rev Chir Orthop Reparatrice Appar Mot
#
#                                             AuthorList             LastAuthor  \
# 0     ['Liu C', 'Sun Z', 'Jiang X', 'Liu B', 'Zhao Y']                 Zhao Y
# 1    ['Davies PS', "O'Brien S", 'Greensmith TS', 'E...        D'Alessandro PA
# 2    ['Sonnery-Cottet B', 'Carrozzo A', 'Poilvache ...              Saithna A
# 3    ['Castellanos Dolk D', 'Sarakatsianos V', 'Wör...              Stålman A
# 4    ['Martinez-Cano JP', 'Gallego A', 'Cuadros J',...  Martinez-Rondanelli A
# ..                                                 ...                    ...
# 217                         ['Carter TR', 'Edinger S']              Edinger S
# 218  ['Yasuda K', 'Tsujino J', 'Tanabe Y', 'Kaneda K']               Kaneda K
# 219                                     ["O'Neill DB"]             O'Neill DB
# 220  ['Yasuda K', 'Tsujino J', 'Ohkoshi Y', 'Tanabe...               Kaneda K
# 221                      ['Goertzen M', 'Schulitz KP']            Schulitz KP
#
#                                                  Title Volume Issue  ...  \
# 0    Cross-education effects of healthy-side lower-...    NaN   NaN  ...
# 1    A single-tendon semitendinosus autograft resul...     18   NaN  ...
# 2    Anterior cruciate ligament reconstruction comb...     62   NaN  ...
# 3    Semitendinosus vs quadriceps tendon autograft ...     26     1  ...
# 4    Similar results with quadrupled semitendinosus...     12     3  ...
# ..                                                 ...    ...   ...  ...
# 217  Isokinetic evaluation of anterior cruciate lig...     15     2  ...
# 218  Effects of initial graft tension on clinical o...     25     1  ...
# 219  Arthroscopically assisted reconstruction of th...     78     6  ...
# 220  Graft site morbidity with autogenous semitendi...     23     6  ...
# 221  [Isolated intraarticular plasty of the semiten...     80     2  ...
#
#                               DOI  \
# 0      10.1186/s13018-026-06776-6
# 1    10.1016/j.jisako.2026.101089
# 2    10.1016/j.lanepe.2025.101561
# 3      10.1186/s12891-025-09183-w
# 4              10.1002/jeo2.70399
# ..                            ...
# 217   10.1053/ar.1999.v15.0150161
# 218    10.1177/036354659702500120
# 219                           NaN
# 220    10.1177/036354659502300613
# 221                           NaN
#
#                                                History References HasAbstract  \
# 0    ['2025/12/30 00:00', '2026/02/18 00:00', '2026...         []           1
# 1    ['2026/01/05 00:00', '2026/02/18 00:00', '2026...         []           1
# 2    ['2025/07/18 00:00', '2025/10/31 00:00', '2025...         []           1
# 3    ['2025/03/25 00:00', '2025/09/03 00:00', '2025...         []           1
# 4    ['2025/04/11 00:00', '2025/06/05 00:00', '2025...         []           1
# ..                                                 ...        ...         ...
# 217  ['1999/04/21 00:00', '1999/04/21 00:01', '1999...         []           1
# 218  ['1997/01/01 00:00', '1997/01/01 00:01', '1997...         []           1
# 219  ['1996/06/01 00:00', '1996/06/01 00:01', '1996...         []           1
# 220  ['1995/11/01 00:00', '1995/11/01 00:01', '1995...         []           1
# 221  ['1994/01/01 00:00', '1994/01/01 00:01', '1994...         []           1
#
#     PmcRefCount                                    FullJournalName  \
# 0             0        Journal of orthopaedic surgery and research
# 1             0  Journal of ISAKOS : joint disorders & orthopae...
# 2            42                 The Lancet regional health. Europe
# 3            60                      BMC musculoskeletal disorders
# 4            33               Journal of experimental orthopaedics
# ..          ...                                                ...
# 217           0  Arthroscopy : the journal of arthroscopic & re...
# 218           0            The American journal of sports medicine
# 219           0  The Journal of bone and joint surgery. America...
# 220           0            The American journal of sports medicine
# 221           0  Revue de chirurgie orthopedique et reparatrice...
#
#                            ELocationID                         SO  \
# 0      doi: 10.1186/s13018-026-06776-6               2026 Mar 13;
# 1    doi: 10.1016/j.jisako.2026.101089      2026 Feb 23;18:101089
# 2    doi: 10.1016/j.lanepe.2025.101561         2026 Mar;62:101561
# 3      doi: 10.1186/s12891-025-09183-w      2025 Oct 13;26(1):951
# 4              doi: 10.1002/jeo2.70399      2025 Jul;12(3):e70399
# ..                                 ...                        ...
# 217                                NaN      1999 Mar;15(2):169-72
# 218                                NaN  1997 Jan-Feb;25(1):99-106
# 219                                NaN      1996 Jun;78(6):803-13
# 220                                NaN  1995 Nov-Dec;23(6):706-14
# 221                                NaN           1994;80(2):113-7
#
#                                               abstract  year
# 0    OBJECTIVE: Based on cross-education theory, th...  2026
# 1    INTRODUCTION: Magnetic resonance imaging has b...  2026
# 2    BACKGROUND: Anterior Cruciate Ligament (ACL) r...  2026
# 3    BACKGROUND: Anterior cruciate ligament (ACL) r...  2025
# 4    PURPOSE: to compare quadrupled semitendinosus ...  2025
# ..                                                 ...   ...
# 217  The purpose of the study was to compare the ha...  1999
# 218  We conducted a prospective, randomized, short-...  1997
# 219  One hundred and twenty-seven patients who had ...  1996
# 220  To distinguish between morbidity caused by har...  1995
# 221  MATERIAL AND METHODS: In a prospective study w...  1994
#
# [222 rows x 29 columns]
#      Unnamed: 0      pmid       PubDate     EPubDate  \
# 0             0  41803188    2026 Mar 9   2026 Mar 9
# 1             1  41761462      2026 Mar          NaN
# 2             2  41682670   2026 Jan 26  2026 Jan 26
# 3             3  41562143   2026 Jan 21  2026 Jan 21
# 4             4  41522461      2026 Jan   2026 Jan 8
# ..          ...       ...           ...          ...
# 238         238   3303978  1987 May-Jun          NaN
# 239         239   3491982      1986 Nov          NaN
# 240         240   3896609      1985 Sep          NaN
# 241         241   3839558      1985 Jun          NaN
# 242         242    420388  1979 Jan-Feb          NaN
#
#                                   Source  \
# 0                                Sci Rep
# 1                           J Orthop Res
# 2                             J Clin Med
# 3    Knee Surg Sports Traumatol Arthrosc
# 4                    Orthop J Sports Med
# ..                                   ...
# 238                      Am J Sports Med
# 239                          Orthopedics
# 240                Clin Orthop Relat Res
# 241                 Med Sci Sports Exerc
# 242                      Am J Sports Med
#
#                                             AuthorList       LastAuthor  \
# 0    ['Abel R', 'Niederer D', 'Glowa A', 'Hansen N'...      Offerhaus C
# 1    ['Dennis JD', 'Edison AE', 'Birchmeier TB', 'P...     Blackburn JT
# 2    ['Blanco-López L', 'Nácher-Moltò I', 'Sánchez-...  Reina-Abellán J
# 3    ['Vendrig T', 'Keizer MNJ', 'Brouwer RW', 'Hou...    Hoogeslag RAG
# 4    ['Johns WL', 'Voskeridjian A', 'Miltenberg B',...        Hammoud S
# ..                                                 ...              ...
# 238  ['Sisk TD', 'Stralka SW', 'Deering MB', 'Griff...       Griffin JW
# 239  ['Arvidsson I', 'Arvidsson H', 'Eriksson E', '...        Jansson E
# 240  ['Odensten M', 'Hamberg P', 'Nordin M', 'Lysho...      Gillquist J
# 241             ['Vegso JJ', 'Genuario SE', 'Torg JS']          Torg JS
# 242                       ['Häggmark T', 'Eriksson E']       Eriksson E
#
#                                                  Title  Volume Issue  ...  \
# 0    Effectiveness of exercise prehabilitation befo...    16.0     1  ...
# 1    Whole Body Vibration Acutely Decreases Medial ...    44.0     3  ...
# 2    Effectiveness of Transcutaneous and Percutaneo...    15.0     3  ...
# 3    Similar dynamic tibiofemoral movements during ...     NaN   NaN  ...
# 4    Regional Anesthesia Utilizing Liposomal Bupiva...    14.0     1  ...
# ..                                                 ...     ...   ...  ...
# 238  Effect of electrical stimulation on quadriceps...    15.0     3  ...
# 239  Prevention of quadriceps wasting after immobil...     9.0    11  ...
# 240  Surgical or conservative treatment of the acut...     NaN   198  ...
# 241  Maintenance of hamstring strength following kn...    17.0     3  ...
# 242  Cylinder or mobile cast brace after knee ligam...     7.0     1  ...
#
#                                DOI  \
# 0       10.1038/s41598-026-41576-2
# 1                10.1002/jor.70166
# 2              10.3390/jcm15030989
# 3                10.1002/ksa.70275
# 4        10.1177/23259671251401596
# ..                             ...
# 238     10.1177/036354658701500304
# 239  10.3928/0147-7447-19861101-08
# 240                            NaN
# 241                            NaN
# 242     10.1177/036354657900700111
#
#                                                History References HasAbstract  \
# 0    ['2025/05/16 00:00', '2026/02/20 00:00', '2026...         []           1
# 1    ['2026/01/29 00:00', '2025/10/22 00:00', '2026...         []           1
# 2    ['2025/12/23 00:00', '2026/01/15 00:00', '2026...         []           1
# 3    ['2025/12/08 00:00', '2025/10/13 00:00', '2025...         []           1
# 4    ['2025/10/23 00:00', '2025/10/28 00:00', '2026...         []           1
# ..                                                 ...        ...         ...
# 238  ['1987/05/01 00:00', '1987/05/01 00:01', '1987...         []           1
# 239  ['1986/11/01 00:00', '1986/11/01 00:01', '1986...         []           1
# 240  ['1985/09/01 00:00', '1985/09/01 00:01', '1985...         []           1
# 241  ['1985/06/01 00:00', '1985/06/01 00:01', '1985...         []           1
# 242  ['1979/01/01 00:00', '1979/01/01 00:01', '1979...         []           1
#
#     PmcRefCount                                    FullJournalName  \
# 0            50                                 Scientific reports
# 1             0  Journal of orthopaedic research : official pub...
# 2            94                       Journal of clinical medicine
# 3             0  Knee surgery, sports traumatology, arthroscopy...
# 4            42             Orthopaedic journal of sports medicine
# ..          ...                                                ...
# 238           0            The American journal of sports medicine
# 239           0                                        Orthopedics
# 240           0         Clinical orthopaedics and related research
# 241           0        Medicine and science in sports and exercise
# 242           0            The American journal of sports medicine
#
#                          ELocationID                                SO  \
# 0    doi: 10.1038/s41598-026-41576-2                  2026 Mar 9;16(1)
# 1             doi: 10.1002/jor.70166             2026 Mar;44(3):e70166
# 2           doi: 10.3390/jcm15030989                 2026 Jan 26;15(3)
# 3             doi: 10.1002/ksa.70275                      2026 Jan 21;
# 4     doi: 10.1177/23259671251401596  2026 Jan;14(1):23259671251401596
# ..                               ...                               ...
# 238                              NaN         1987 May-Jun;15(3):215-20
# 239                              NaN            1986 Nov;9(11):1519-28
# 240                              NaN              1985 Sep;(198):87-93
# 241                              NaN              1985 Jun;17(3):376-9
# 242                              NaN           1979 Jan-Feb;7(1):48-56
#
#                                               abstract  year
# 0    Objective: To compare the effectiveness of an ...  2026
# 1    Investigating the loading environment of the t...  2026
# 2    Background/Objectives: Quadriceps arthrogenic ...  2026
# 3    PURPOSE: Dynamic tibiofemoral movements follow...  2026
# 4    BACKGROUND: Perioperative nerve blocks are com...  2026
# ..                                                 ...   ...
# 238  The effect of prolonged daily electrical stimu...  1987
# 239  Eighteen male and 20 female patients who under...  1986
# 240  In a prospective study, 90 consecutive patient...  1985
# 241  Following a variety of surgical procedures on ...  1985
# 242  Sixteen patients participated in a prospective...  1979
#
# [243 rows x 29 columns]
#    Unnamed: 0      pmid      PubDate     EPubDate                   Source  \
# 0           0  39714511  2024 Dec 23  2024 Dec 23  Arch Orthop Trauma Surg
# 1           1  29421837     2018 Nov   2018 Feb 8              J Knee Surg
#
#                                           AuthorList LastAuthor  \
# 0  ['Butt U', 'Vuletic F', 'Shaikh MAA', 'Amanull...    Khan ZA
# 1  ['Bi M', 'Zhao C', 'Zhang S', 'Yao B', 'Hong Z...       Bi Q
#
#                                                Title  Volume  Issue  ...  \
# 0  5-years outcomes following arthroscopic anteri...     145      1  ...
# 1  All-Inside Single-Bundle Reconstruction of the...      31     10  ...
#
#                           DOI  \
# 0  10.1007/s00402-024-05639-1
# 1      10.1055/s-0038-1627466
#
#                                              History  References HasAbstract  \
# 0  ['2024/08/03 00:00', '2024/10/29 00:00', '2024...          []           1
# 1  ['2018/02/09 06:00', '2019/01/01 06:00', '2018...          []           1
#
#   PmcRefCount                             FullJournalName  \
# 0          34  Archives of orthopaedic and trauma surgery
# 1           0                 The journal of knee surgery
#
#                        ELocationID                         SO  \
# 0  doi: 10.1007/s00402-024-05639-1      2024 Dec 23;145(1):85
# 1      doi: 10.1055/s-0038-1627466  2018 Nov;31(10):1022-1030
#
#                                             abstract  year
# 0  AIMS: This study presents clinical outcomes, f...  2024
# 1  The anterior half of the peroneus longus tendo...  2018
#
# [2 rows x 29 columns]
#    Unnamed: 0      pmid      PubDate     EPubDate  \
# 0           0  27682300     2016 Aug          NaN
# 1           1  24488793     2014 Dec  2014 Jan 31
# 2           2  23538044     2013 May  2013 Mar 26
# 3           3  23369444     2013 Mar  2013 Jan 28
# 4           4  22732367     2012 Oct  2012 Jun 23
# 5           5  21290116     2011 May   2011 Feb 3
# 6           6  15363236  2004 Aug 22          NaN
#
#                                 Source  \
# 0                     Acta Orthop Belg
# 1                          J Knee Surg
# 2                          Arthroscopy
# 3                          Arthroscopy
# 4                          Arthroscopy
# 5  Knee Surg Sports Traumatol Arthrosc
# 6               Zhonghua Wai Ke Za Zhi
#
#                                           AuthorList     LastAuthor  \
# 0       ['Noh JH', 'Kyiung HS', 'Yoon KH', 'Roh YH']         Roh YH
# 1  ['Koyonos L', 'Owsley K', 'Vollmer E', 'Limpis...  Gambardella R
# 2  ['Noh JH', 'Roh YH', 'Yang BG', 'Yi SR', 'Lee ...         Lee SY
# 3  ['Noh JH', 'Yang BG', 'Yi SR', 'Roh YH', 'Lee ...         Lee JS
# 4  ['Noh JH', 'Yang BG', 'Yi SR', 'Roh YH', 'Lee ...         Lee JS
# 5  ['Noh JH', 'Yi SR', 'Song SJ', 'Kim SW', 'Kim W']          Kim W
# 6  ['Sun K', 'Tang JW', 'Xu Q', 'Liu XY', 'Zhou L...         Sun YJ
#
#                                                Title  Volume  Issue  ...  \
# 0  Supplementary tibial fixation in anterior cruc...      82      2  ...
# 1  Preoperative cryotherapy use in anterior cruci...      27      6  ...
# 2  Femoral tunnel position on conventional magnet...      29      5  ...
# 3  Single-bundle anterior cruciate ligament recon...      29      3  ...
# 4  Hybrid tibial fixation for anterior cruciate l...      28     10  ...
# 5  Comparison between hamstring autograft and fre...      19      5  ...
# 6  [A prospective study of the anterior cruciate ...      42     16  ...
#
#                                              History References HasAbstract  \
# 0  ['2016/09/30 06:00', '2016/09/30 06:00', '2017...         []           1
# 1  ['2014/02/04 06:00', '2014/02/04 06:00', '2015...         []           1
# 2  ['2012/04/06 00:00', '2013/01/14 00:00', '2013...         []           1
# 3  ['2012/02/23 00:00', '2012/10/21 00:00', '2012...         []           1
# 4  ['2011/09/30 00:00', '2012/03/11 00:00', '2012...         []           1
# 5  ['2010/07/01 00:00', '2010/12/27 00:00', '2011...         []           1
# 6  ['2004/09/15 05:00', '2006/11/01 09:00', '2004...         []           1
#
#   PmcRefCount                                    FullJournalName  \
# 0           0                          Acta orthopaedica Belgica
# 1           0                        The journal of knee surgery
# 2           0  Arthroscopy : the journal of arthroscopic & re...
# 3           0  Arthroscopy : the journal of arthroscopic & re...
# 4           0  Arthroscopy : the journal of arthroscopic & re...
# 5           0  Knee surgery, sports traumatology, arthroscopy...
# 6           0  Zhonghua wai ke za zhi [Chinese journal of sur...
#
#                          ELocationID                         SO  \
# 0                                NaN     2016 Aug;82(2):358-364
# 1        doi: 10.1055/s-0034-1367730      2014 Dec;27(6):479-84
# 2  doi: 10.1016/j.arthro.2013.01.025      2013 May;29(5):882-90
# 3  doi: 10.1016/j.arthro.2012.10.023      2013 Mar;29(3):507-13
# 4  doi: 10.1016/j.arthro.2012.03.012     2012 Oct;28(10):1540-6
# 5     doi: 10.1007/s00167-010-1388-6      2011 May;19(5):816-22
# 6                                NaN  2004 Aug 22;42(16):989-92
#
#                             DOI  \
# 0                           NaN
# 1        10.1055/s-0034-1367730
# 2  10.1016/j.arthro.2013.01.025
# 3  10.1016/j.arthro.2012.10.023
# 4  10.1016/j.arthro.2012.03.012
# 5     10.1007/s00167-010-1388-6
# 6                           NaN
#
#                                             abstract  year
# 0  We compare clinical outcomes of two different ...  2016
# 1  Unrelieved postoperative pain may impair rehab...  2014
# 2  PURPOSE: The purpose of this study was to comp...  2013
# 3  PURPOSE: The purpose was to prospectively comp...  2013
# 4  PURPOSE: To compare clinical outcomes of tibia...  2012
# 5  PURPOSE: This study is to compare the clinical...  2011
# 6  OBJECTIVE: To compare the clinical outcomes an...  2004
#
# [7 rows x 29 columns]
#    Unnamed: 0      pmid      PubDate     EPubDate                  Source  \
# 0           0  41827078  2026 Mar 13  2026 Mar 13       J Orthop Surg Res
# 1           1  35114581     2022 Mar  2022 Jan 20               J Biomech
# 2           2  31828089         2019  2019 Nov 15          Biomed Res Int
# 3           3  28840143     2017 Aug   2017 Aug 7     Orthop J Sports Med
# 4           4  27876265     2016 Dec  2016 Nov 18                    Knee
# 5           5  27570169     2017 Jan  2016 Aug 25             Arthroscopy
# 6           6  26311445     2015 Oct  2015 Aug 26         Am J Sports Med
# 7           7  25891223     2015 Jul  2015 Apr 17             Arthroscopy
# 8           8  15363236  2004 Aug 22          NaN  Zhonghua Wai Ke Za Zhi
#
#                                           AuthorList    LastAuthor  \
# 0   ['Liu C', 'Sun Z', 'Jiang X', 'Liu B', 'Zhao Y']        Zhao Y
# 1  ['Zandiyeh P', 'Parola LR', 'Fleming BC', 'Bev...  Beveridge JE
# 2  ['Kaya D', 'Guney-Deniz H', 'Sayaca C', 'Calik...      Doral MN
# 3                           ['Rose M', 'Crawford D']    Crawford D
# 4  ['Rose MB', 'Domes C', 'Farooqi M', 'Crawford ...   Crawford DC
# 5  ['Wasserman BR', 'Singh BC', 'Kaplan DJ', 'Wei...    Strauss EJ
# 6  ['Bottoni CR', 'Smith EL', 'Shaha J', 'Shaha S...     Rowles DJ
# 7  ['Li J', 'Wang J', 'Li Y', 'Shao D', 'You X', ...        Shen Y
# 8  ['Sun K', 'Tang JW', 'Xu Q', 'Liu XY', 'Zhou L...        Sun YJ
#
#                                                Title  Volume  Issue  ...  \
# 0  Cross-education effects of healthy-side lower-...     NaN    NaN  ...
# 1  Wavelet analysis reveals differential lower li...   133.0    NaN  ...
# 2  Effects on Lower Extremity Neuromuscular Contr...  2019.0    NaN  ...
# 3  Allograft Maturation After Reconstruction of t...     5.0    8.0  ...
# 4  A prospective randomized comparison of two dis...    23.0    6.0  ...
# 5  Braking Reaction Time After Right-Knee Anterio...    33.0    1.0  ...
# 6  Autograft Versus Allograft Anterior Cruciate L...    43.0   10.0  ...
# 7  A Prospective Randomized Study of Anterior Cru...    31.0    7.0  ...
# 8  [A prospective study of the anterior cruciate ...    42.0   16.0  ...
#
#                               DOI  \
# 0      10.1186/s13018-026-06776-6
# 1  10.1016/j.jbiomech.2022.110957
# 2            10.1155/2019/1694695
# 3        10.1177/2325967117719695
# 4      10.1016/j.knee.2016.08.011
# 5    10.1016/j.arthro.2016.05.043
# 6        10.1177/0363546515596406
# 7    10.1016/j.arthro.2015.02.033
# 8                             NaN
#
#                                              History  References HasAbstract  \
# 0  ['2025/12/30 00:00', '2026/02/18 00:00', '2026...          []           1
# 1  ['2021/06/22 00:00', '2022/01/05 00:00', '2022...          []           1
# 2  ['2019/10/01 00:00', '2019/10/31 00:00', '2019...          []           1
# 3  ['2017/08/26 06:00', '2017/08/26 06:00', '2017...          []           1
# 4  ['2016/04/26 00:00', '2016/08/24 00:00', '2016...          []           1
# 5  ['2015/12/03 00:00', '2016/05/27 00:00', '2016...          []           1
# 6  ['2015/08/28 06:00', '2015/08/28 06:00', '2016...          []           1
# 7  ['2014/06/17 00:00', '2015/02/01 00:00', '2015...          []           1
# 8  ['2004/09/15 05:00', '2006/11/01 09:00', '2004...          []           1
#
#   PmcRefCount                                    FullJournalName  \
# 0           0        Journal of orthopaedic surgery and research
# 1          49                            Journal of biomechanics
# 2          27                      BioMed research international
# 3          16             Orthopaedic journal of sports medicine
# 4           0                                           The Knee
# 5           0  Arthroscopy : the journal of arthroscopic & re...
# 6           0            The American journal of sports medicine
# 7           0  Arthroscopy : the journal of arthroscopic & re...
# 8           0  Zhonghua wai ke za zhi [Chinese journal of sur...
#
#                            ELocationID                              SO  \
# 0      doi: 10.1186/s13018-026-06776-6                    2026 Mar 13;
# 1  doi: 10.1016/j.jbiomech.2022.110957             2022 Mar;133:110957
# 2            doi: 10.1155/2019/1694695               2019;2019:1694695
# 3        doi: 10.1177/2325967117719695  2017 Aug;5(8):2325967117719695
# 4      doi: 10.1016/j.knee.2016.08.011        2016 Dec;23(6):1112-1120
# 5    doi: 10.1016/j.arthro.2016.05.043          2017 Jan;33(1):173-180
# 6        doi: 10.1177/0363546515596406          2015 Oct;43(10):2501-9
# 7    doi: 10.1016/j.arthro.2015.02.033         2015 Jul;31(7):1296-302
# 8                                  NaN       2004 Aug 22;42(16):989-92
#
#                                             abstract  year
# 0  OBJECTIVE: Based on cross-education theory, th...  2026
# 1  The purpose of this study was to test whether ...  2022
# 2  OBJECTIVE: The purpose of this study was to de...  2019
# 3  BACKGROUND: Allograft healing (ligamentization...  2017
# 4  BACKGROUND: Conduct a prospective randomized s...  2016
# 5  PURPOSE: To determine when patients recover th...  2017
# 6  BACKGROUND: The use of allografts for anterior...  2015
# 7  PURPOSE: To compare the results of patients wh...  2015
# 8  OBJECTIVE: To compare the clinical outcomes an...  2004
#
# [9 rows x 29 columns]
#                                                 Title  Original Title  \
# 0   Similar dynamic tibiofemoral movements during ...             NaN
# 1   Regional Anesthesia Utilizing Liposomal Bupiva...             NaN
# 2   Extended Post-Operative Oral Tranexamic Acid D...             NaN
# 3   Postoperative Pain and Opioid Usage With Combi...             NaN
# 4   Liposomal Bupivacaine-Based Regional Anesthesi...             NaN
# ..                                                ...             ...
# 68  A prospective, randomized comparison of semite...             NaN
# 69  Intra-articular Drain Versus No Drain After Ar...             NaN
# 70  A comparison of bone-patellar tendon-bone and ...             NaN
# 71  Clinical evaluation of arthroscopically assist...             NaN
# 72  Anterior cruciate ligament reconstruction: Bon...             NaN
#
#                                          Author Names  \
# 0   Vendrig T., Keizer M.N.J., Brouwer R.W., Houdi...
# 1   Johns W.L., Voskeridjian A., Miltenberg B., Mu...
# 2                                                 NaN
# 3   Rao N., Triana J., Avila A., Campbell K.A., Al...
# 4   Miltenberg B., Voskeridjian A., Dodson C., Cic...
# ..                                                ...
# 68  Sajovic M., Vengust V., Komadina R., Tavcar R....
# 69  McCormack R.G., Greenhow R.J., Fogagnolo F., S...
# 70  Matsumoto A., Yoshiya S., Muratsu H., Yagi M.,...
# 71  Ibrahim S.A.-R., Al-Kussary I.M., Al-Misfer A....
# 72  Aglietti P., Giron F., Buzzi R., Biddau F., Sa...
#
#                                      Author Addresses  \
# 0   (Vendrig T.; Keizer M.N.J.; Houdijk H.) Center...
# 1   (Johns W.L., william.johns@jefferson.edu; Milt...
# 2                                                 NaN
# 3   (Rao N.; Triana J.; Avila A.; Campbell K.A.; A...
# 4   (Miltenberg B.; Voskeridjian A.; Dodson C.; Ci...
# ..                                                ...
# 68  (Sajovic M., sajovic@siol.com; Vengust V.; Kom...
# 69  (McCormack R.G., mccormac@interchange.ubc.ca; ...
# 70  (Matsumoto A.; Yoshiya S.; Muratsu H.; Kurosak...
# 71  (Ibrahim S.A.-R., samirabdulrazik@yahoo.com; A...
# 72  (Aglietti P.; Giron F., ortosec@unifi.it; Buzz...
#
#                                Correspondence Address  Editors  \
# 0                                                 NaN      NaN
# 1   W.L. Johns, Rothman Orthopaedic Institute, 833...      NaN
# 2                                                 NaN      NaN
# 3                                                 NaN      NaN
# 4    B. Miltenberg, Rothman Institute, United States.      NaN
# ..                                                ...      ...
# 68  M. Sajovic, Department of Orthopedics and Spor...      NaN
# 69  R.G. McCormack, Department of Orthopedic Surge...      NaN
# 70  R. Kuroda, Department of Orthopaedic Surgery, ...      NaN
# 71  S.A.-R. Ibrahim, Orthopaedic Unit, Al Razi Ort...      NaN
# 72  P. Aglietti, First Orthopaedic Clinic, Univers...      NaN
#
#    AiP/IP Entry Date Full Record Entry Date  \
# 0         2026-01-28                    NaN
# 1         2026-01-13             2026-01-20
# 2         2025-10-13             2025-10-13
# 3                NaN             2025-05-13
# 4                NaN             2025-10-31
# ..               ...                    ...
# 68               NaN             2006-11-21
# 69               NaN             2006-08-22
# 70               NaN             2006-02-21
# 71               NaN             2005-04-18
# 72               NaN             2004-11-05
#
#                                                Source  \
# 0   Knee surgery, sports traumatology, arthroscopy...
# 1   Orthopaedic Journal of Sports Medicine (2026) ...
# 2   clinicaltrials.gov (2025). Date of Publication...
# 3   The American journal of sports medicine (2025)...
# 4   Orthopaedic Journal of Sports Medicine (2025) ...
# ..                                                ...
# 68  American Journal of Sports Medicine (2006) 34:...
# 69  Arthroscopy - Journal of Arthroscopic and Rela...
# 70  American Journal of Sports Medicine (2006) 34:...
# 71  Arthroscopy - Journal of Arthroscopic and Rela...
# 72  Journal of Bone and Joint Surgery (2004) 86:10...
#
#                                          Source title  ...  Article Language  \
# 0   Knee surgery, sports traumatology, arthroscopy...  ...           English
# 1              Orthopaedic Journal of Sports Medicine  ...           English
# 2                                  clinicaltrials.gov  ...           English
# 3             The American journal of sports medicine  ...           English
# 4              Orthopaedic Journal of Sports Medicine  ...           English
# ..                                                ...  ...               ...
# 68                American Journal of Sports Medicine  ...           English
# 69  Arthroscopy - Journal of Arthroscopic and Rela...  ...           English
# 70                American Journal of Sports Medicine  ...           English
# 71  Arthroscopy - Journal of Arthroscopic and Rela...  ...           English
# 72                  Journal of Bone and Joint Surgery  ...           English
#
#     Summary Language Embase Accession ID  Medline PMID           PUI  \
# 0            English                 NaN    41562143.0    L649979470
# 1            English                 NaN           NaN   L2042770284
# 2            English                 NaN           NaN  LNCT07115056
# 3            English                 NaN    40308075.0    L647267499
# 4            English                 NaN           NaN    L648943823
# ..               ...                 ...           ...           ...
# 68           English        2.006547e+09    16923826.0     L44704247
# 69           English        2.006375e+09    16904589.0     L44175785
# 70           English        2.006052e+09    16282583.0     L43152957
# 71           English        2.005145e+09    15800520.0     L40432344
# 72           English                 NaN    15466722.0     L39349947
#
#                                  DOI  \
# 0                  10.1002/ksa.70275
# 1          10.1177/23259671251401596
# 2                                NaN
# 3          10.1177/03635465251328609
# 4           10.1177/2325967125S00004
# ..                               ...
# 68          10.1177/0363546506290726
# 69      10.1016/j.arthro.2006.05.004
# 70          10.1177/0363546505279919
# 71      10.1016/j.arthro.2004.12.002
# 72  10.2106/00004623-200410000-00004
#
#                                        Full Text Link  \
# 0                 http://dx.doi.org/10.1002/ksa.70275
# 1         http://dx.doi.org/10.1177/23259671251401596
# 2        https://clinicaltrials.gov/study/NCT07115056
# 3         http://dx.doi.org/10.1177/03635465251328609
# 4          http://dx.doi.org/10.1177/2325967125S00004
# ..                                                ...
# 68         http://dx.doi.org/10.1177/0363546506290726
# 69     http://dx.doi.org/10.1016/j.arthro.2006.05.004
# 70         http://dx.doi.org/10.1177/0363546505279919
# 71     http://dx.doi.org/10.1016/j.arthro.2004.12.002
# 72  http://dx.doi.org/10.2106/00004623-200410000-0...
#
#                                           Embase Link  \
# 0   https://www.embase.com/search/results?subactio...
# 1   https://www.embase.com/search/results?subactio...
# 2   https://www.embase.com/search/results?subactio...
# 3   https://www.embase.com/search/results?subactio...
# 4   https://www.embase.com/search/results?subactio...
# ..                                                ...
# 68  https://www.embase.com/search/results?subactio...
# 69  https://www.embase.com/search/results?subactio...
# 70  https://www.embase.com/search/results?subactio...
# 71  https://www.embase.com/search/results?subactio...
# 72  https://www.embase.com/search/results?subactio...
#
#                                         Open URL Link  \
# 0   https://catalyst.library.jhu.edu/openurl/01JHU...
# 1   https://catalyst.library.jhu.edu/openurl/01JHU...
# 2                                                 NaN
# 3   https://catalyst.library.jhu.edu/openurl/01JHU...
# 4   https://catalyst.library.jhu.edu/openurl/01JHU...
# ..                                                ...
# 68  https://catalyst.library.jhu.edu/openurl/01JHU...
# 69  https://catalyst.library.jhu.edu/openurl/01JHU...
# 70  https://catalyst.library.jhu.edu/openurl/01JHU...
# 71  https://catalyst.library.jhu.edu/openurl/01JHU...
# 72  https://catalyst.library.jhu.edu/openurl/01JHU...
#
#                                             Copyright
# 0   This record is sourced from MEDLINE/PubMed, a ...
# 1   Copyright 2026 Elsevier B.V., All rights reser...
# 2   This record is sourced from clinicaltrials.gov...
# 3   This record is sourced from MEDLINE/PubMed, a ...
# 4   Copyright 2025 Elsevier B.V., All rights reser...
# ..                                                ...
# 68  Copyright 2010 Elsevier B.V., All rights reser...
# 69  Copyright 2010 Elsevier B.V., All rights reser...
# 70  Copyright 2010 Elsevier B.V., All rights reser...
# 71  Copyright 2010 Elsevier B.V., All rights reser...
# 72  Copyright 2022 Elsevier B.V., All rights reser...
#
# [73 rows x 49 columns]
#                                                 Title  Original Title  \
# 0   A single-tendon semitendinosus autograft resul...             NaN
# 1   Cross-education effects of healthy-side lower-...             NaN
# 2   A semitendinosus with adjustable button graft ...             NaN
# 3   5-years outcomes following arthroscopic anteri...             NaN
# 4   Semitendinosus vs quadriceps tendon autograft ...             NaN
# ..                                                ...             ...
# 92  A prospective, randomized comparison of semite...             NaN
# 93  Biodegradable and metallic interference screws...             NaN
# 94  A comparison of bone-patellar tendon-bone and ...             NaN
# 95  Clinical evaluation of arthroscopically assist...             NaN
# 96  Anterior cruciate ligament reconstruction: Bon...             NaN
#
#                                          Author Names  \
# 0   Davies P.S., O'Brien S., Greensmith T.S., Eber...
# 1           Liu C., Sun Z., Jiang X., Liu B., Zhao Y.
# 2   Lawless A.M., Ebert J.R., Edwards P.K., Malik ...
# 3   Butt U., Vuletic F., Shaikh M.A.A., Amanullah,...
# 4   Castellanos Dolk D., Sarakatsianos V., Wörner ...
# ..                                                ...
# 92  Sajovic M., Vengust V., Komadina R., Tavcar R....
# 93  Laxdal G., Kartus J., Eriksson B.I., Faxén E.,...
# 94  Matsumoto A., Yoshiya S., Muratsu H., Yagi M.,...
# 95  Ibrahim S.A.-R., Al-Kussary I.M., Al-Misfer A....
# 96  Aglietti P., Giron F., Buzzi R., Biddau F., Sa...
#
#                                      Author Addresses  \
# 0   (Davies P.S., petersedavies@doctors.org.uk; O'...
# 1   (Liu C.) Department of Sports Training, Tianji...
# 2   (Lawless A.M.; Davies P.S.E.; D'Alessandro P.A...
# 3   (Butt U.; Shaikh M.A.A.; Amanullah; Rehman G.U...
# 4   (Castellanos Dolk D., daniel.castellanos.dolk@...
# ..                                                ...
# 92  (Sajovic M., sajovic@siol.com; Vengust V.; Kom...
# 93  (Laxdal G., gauti.laxdal@vgregion.se; Kartus J...
# 94  (Matsumoto A.; Yoshiya S.; Muratsu H.; Kurosak...
# 95  (Ibrahim S.A.-R., samirabdulrazik@yahoo.com; A...
# 96  (Aglietti P.; Giron F., ortosec@unifi.it; Buzz...
#
#                                Correspondence Address  Editors  \
# 0   P.S. Davies, Department of Trauma and Orthopae...      NaN
# 1                                                 NaN      NaN
# 2                                                 NaN      NaN
# 3   A. Stålman, Department of Molecular Medicine a...      NaN
# 4   D. Castellanos Dolk, Department of Molecular M...      NaN
# ..                                                ...      ...
# 92  M. Sajovic, Department of Orthopedics and Spor...      NaN
# 93  G. Laxdal, Department of Orthopaedics, Sahlgre...      NaN
# 94  R. Kuroda, Department of Orthopaedic Surgery, ...      NaN
# 95  S.A.-R. Ibrahim, Orthopaedic Unit, Al Razi Ort...      NaN
# 96  P. Aglietti, First Orthopaedic Clinic, Univers...      NaN
#
#    AiP/IP Entry Date Full Record Entry Date  \
# 0         2026-04-07                    NaN
# 1         2026-03-26                    NaN
# 2         2025-05-22             2026-02-05
# 3         2024-12-26             2025-01-10
# 4         2025-10-20             2025-10-24
# ..               ...                    ...
# 92               NaN             2006-11-21
# 93               NaN             2006-10-01
# 94               NaN             2006-02-21
# 95               NaN             2005-04-18
# 96               NaN             2004-11-05
#
#                                                Source  \
# 0   Journal of ISAKOS (2026) 18 Article Number: 10...
# 1   Journal of orthopaedic surgery and research (2...
# 2   Knee surgery, sports traumatology, arthroscopy...
# 3   Archives of Orthopaedic and Trauma Surgery (20...
# 4   BMC Musculoskeletal Disorders (2025) 26:1 Arti...
# ..                                                ...
# 92  American Journal of Sports Medicine (2006) 34:...
# 93  American Journal of Sports Medicine (2006) 34:...
# 94  American Journal of Sports Medicine (2006) 34:...
# 95  Arthroscopy - Journal of Arthroscopic and Rela...
# 96  Journal of Bone and Joint Surgery (2004) 86:10...
#
#                                          Source title  ...  Article Language  \
# 0                                   Journal of ISAKOS  ...           English
# 1         Journal of orthopaedic surgery and research  ...           English
# 2   Knee surgery, sports traumatology, arthroscopy...  ...           English
# 3          Archives of Orthopaedic and Trauma Surgery  ...           English
# 4                       BMC Musculoskeletal Disorders  ...           English
# ..                                                ...  ...               ...
# 92                American Journal of Sports Medicine  ...           English
# 93                American Journal of Sports Medicine  ...           English
# 94                American Journal of Sports Medicine  ...           English
# 95  Arthroscopy - Journal of Arthroscopic and Rela...  ...           English
# 96                  Journal of Bone and Joint Surgery  ...           English
#
#     Summary Language  Embase Accession ID Medline PMID          PUI  \
# 0            English                  NaN   41740851.0  L2044647163
# 1            English                  NaN   41827078.0   L650616806
# 2            English                  NaN   40351242.0   L647350222
# 3            English                  NaN   39714511.0  L2032696887
# 4            English                  NaN   41083992.0  L2040529555
# ..               ...                  ...          ...          ...
# 92           English         2.006547e+09   16923826.0    L44704247
# 93           English         2.006450e+09   16685087.0    L44385849
# ...
# ..                                                ...
# 65  The influence of electromyographic biofeedback...
# 66  The influence of graft choice on isokinetic mu...
# 67  Early Versus Late Start of Isokinetic Hamstrin...
# 68  Comparison of home versus physical therapy-sup...
# 69  Donor-site morbidity and anterior knee problem...
#
#                                                    SO  ...  \
# 0   ARTHROSCOPY-THE JOURNAL OF ARTHROSCOPIC AND RE...  ...
# 1                                  SCIENTIFIC REPORTS  ...
# 2        KNEE SURGERY SPORTS TRAUMATOLOGY ARTHROSCOPY  ...
# 3                 AMERICAN JOURNAL OF SPORTS MEDICINE  ...
# 4                JOURNAL OF EXPERIMENTAL ORTHOPAEDICS  ...
# ..                                                ...  ...
# 65     BMC SPORTS SCIENCE MEDICINE AND REHABILITATION  ...
# 66       KNEE SURGERY SPORTS TRAUMATOLOGY ARTHROSCOPY  ...
# 67                AMERICAN JOURNAL OF SPORTS MEDICINE  ...
# 68                AMERICAN JOURNAL OF SPORTS MEDICINE  ...
# 69  ARTHROSCOPY-THE JOURNAL OF ARTHROSCOPIC AND RE...  ...
#
#                                       WC  \
# 0   Orthopedics; Sport Sciences; Surgery
# 1             Multidisciplinary Sciences
# 2   Orthopedics; Sport Sciences; Surgery
# 3            Orthopedics; Sport Sciences
# 4                   Orthopedics; Surgery
# ..                                   ...
# 65        Rehabilitation; Sport Sciences
# 66  Orthopedics; Sport Sciences; Surgery
# 67           Orthopedics; Sport Sciences
# 68           Orthopedics; Sport Sciences
# 69  Orthopedics; Sport Sciences; Surgery
#
#                                                 WE  \
# 0   Science Citation Index Expanded (SCI-EXPANDED)
# 1   Science Citation Index Expanded (SCI-EXPANDED)
# 2   Science Citation Index Expanded (SCI-EXPANDED)
# 3   Science Citation Index Expanded (SCI-EXPANDED)
# 4           Emerging Sources Citation Index (ESCI)
# ..                                             ...
# 65          Emerging Sources Citation Index (ESCI)
# 66  Science Citation Index Expanded (SCI-EXPANDED)
# 67  Science Citation Index Expanded (SCI-EXPANDED)
# 68  Science Citation Index Expanded (SCI-EXPANDED)
# 69  Science Citation Index Expanded (SCI-EXPANDED)
#
#                                       SC     GA          PM  \
# 0   Orthopedics; Sport Sciences; Surgery  GE3FD  41946489.0
# 1    Science & Technology - Other Topics  FB6RU  41803188.0
# 2   Orthopedics; Sport Sciences; Surgery  EK0OO  41758993.0
# 3            Orthopedics; Sport Sciences  ED2UX  41733021.0
# 4                   Orthopedics; Surgery  DW5FP  41717284.0
# ..                                   ...    ...         ...
# 65        Rehabilitation; Sport Sciences  V30QR         NaN
# 66  Orthopedics; Sport Sciences; Surgery  750FD  21234542.0
# 67           Orthopedics; Sport Sciences  559ED  20194956.0
# 68           Orthopedics; Sport Sciences  959KR  16002493.0
# 69  Orthopedics; Sport Sciences; Surgery  490LN  11694930.0
#
#                        OA  HC  HP          DA                   UT
# 0                     NaN NaN NaN  2026-04-15  WOS:001734357400001
# 1   Green Submitted, gold NaN NaN  2026-04-15  WOS:001714905500001
# 2                  hybrid NaN NaN  2026-04-15  WOS:001702935900001
# 3         Green Submitted NaN NaN  2026-04-15  WOS:001698340800001
# 4   Green Submitted, gold NaN NaN  2026-04-15  WOS:001693745600001
# ..                    ...  ..  ..         ...                  ...
# 65  Green Submitted, gold NaN NaN  2026-04-15  WOS:000215577600041
# 66        Green Submitted NaN NaN  2026-04-15  WOS:000289529700012
# 67                    NaN NaN NaN  2026-04-15  WOS:000274803800008
# 68                    NaN NaN NaN  2026-04-15  WOS:000231517100002
# 69                    NaN NaN NaN  2026-04-15  WOS:000172053500011
#
# [70 rows x 71 columns]
#   ï»¿PT                                                 AU  BA  BE  GP  \
# 0     J  Butt, U; Vuletic, F; Shaikh, MAA; Amanullah; R... NaN NaN NaN
# 1     J  Park, JY; Fernandes, A; Park, SY; Lim, H; Sayu... NaN NaN NaN
# 2     J  Quinn, M; Albright, A; Testa, E; Ahn, B; Lemme... NaN NaN NaN
# 3     J  Delcogliano, M; Sangiorgio, A; Bensa, A; Andri... NaN NaN NaN
#
#                                                   AF  BF  CA  \
# 0  Butt, Umer; Vuletic, Filip; Shaikh, M. Ali Ahm... NaN NaN
# 1  Park, Jae Yong; Fernandes, Andre; Park, Shin Y... NaN NaN
# 2  Quinn, Matthew; Albright, Alex; Testa, Edward;... NaN NaN
# 3  Delcogliano, Marco; Sangiorgio, Alessandro; Be... NaN NaN
#
#                                                   TI  \
# 0  5-years outcomes following arthroscopic anteri...
# 1  Comparative effectiveness of peroneus longus t...
# 2  Peroneus Longus Tendon Autograft May Present a...
# 3  Platelet-rich plasma augmentation in anterior ...
#
#                                                   SO  ...  \
# 0         ARCHIVES OF ORTHOPAEDIC AND TRAUMA SURGERY  ...
# 1  EUROPEAN JOURNAL OF ORTHOPAEDIC SURGERY AND TR...  ...
# 2  ARTHROSCOPY-THE JOURNAL OF ARTHROSCOPIC AND RE...  ...
# 3       KNEE SURGERY SPORTS TRAUMATOLOGY ARTHROSCOPY  ...
#
#                                      WC  \
# 0                  Orthopedics; Surgery
# 1                  Orthopedics; Surgery
# 2  Orthopedics; Sport Sciences; Surgery
# 3  Orthopedics; Sport Sciences; Surgery
#
#                                                WE  \
# 0  Science Citation Index Expanded (SCI-EXPANDED)
# 1          Emerging Sources Citation Index (ESCI)
# 2  Science Citation Index Expanded (SCI-EXPANDED)
# 3  Science Citation Index Expanded (SCI-EXPANDED)
#
#                                      SC     GA        PM  \
# 0                  Orthopedics; Surgery  R0A5V  39714511
# 1                  Orthopedics; Surgery  A5X5Y  38755499
# 2  Orthopedics; Sport Sciences; Surgery  OM0P8  37898307
# 3  Orthopedics; Sport Sciences; Surgery  OJ6B4  38488226
#
#                         OA  HC  HP          DA                   UT
# 0  Green Submitted, hybrid NaN NaN  2026-04-15  WOS:001388192900002
# 1  Green Submitted, hybrid NaN NaN  2026-04-15  WOS:001226561300002
# 2                      NaN NaN NaN  2026-04-15  WOS:001207575800001
# 3                   hybrid NaN NaN  2026-04-15  WOS:001185182400001
#
# [4 rows x 71 columns]
#   ï»¿PT                                                 AU  BA  BE  GP  \
# 0     J  BusÃ , MF; Zago, M; Buckthorpe, M; Esposito, F... NaN NaN NaN
# 1     J                                 Wang, D; Rodeo, SA NaN NaN NaN
# 2     J              Noh, JH; Kyung, HS; Yoon, KH; Roh, YH NaN NaN NaN
# 3     J  Cvetanovich, GL; Mascarenhas, R; Saccomanno, M... NaN NaN NaN
# 4     J  Moraes, VY; Lenza, M; Tamaoki, MJ; Faloppa, F;... NaN NaN NaN
# 5     J        Noh, JH; Roh, YH; Yang, BG; Yi, SR; Lee, SY NaN NaN NaN
# 6     J        Noh, JH; Yang, BG; Yi, SR; Roh, YH; Lee, JS NaN NaN NaN
# 7     J  Moraes, VY; Lenza, M; Tamaoki, MJ; Faloppa, F;... NaN NaN NaN
# 8     J        Noh, JH; Yang, BG; Yi, SR; Roh, YH; Lee, JS NaN NaN NaN
# 9     J  Taylor, DW; Petrera, M; Hendry, M; Theodoropou... NaN NaN NaN
#
#                                                   AF  BF  CA  \
# 0  Busa, Mattia Fernando; Zago, Matteo; Buckthorp... NaN NaN
# 1                        Wang, Dean; Rodeo, Scott A. NaN NaN
# 2  Noh, Jung Ho; Kyung, Hee Soo; Yoon, Kyoung Ho;... NaN NaN
# 3  Cvetanovich, Gregory L.; Mascarenhas, Randy; S... NaN NaN
# 4  Moraes, Vinicius Y.; Lenza, Mario; Tamaoki, Ma... NaN NaN
# 5  Noh, Jung Ho; Roh, Young Hak; Yang, Bo Gyu; Yi... NaN NaN
# 6  Noh, Jung Ho; Yang, Bo Gyu; Yi, Seung Rim; Roh... NaN NaN
# 7  Moraes, Vinicius Y.; Lenza, Mario; Tamaoki, Ma... NaN NaN
# 8  Noh, Jung Ho; Yang, Bo Gyu; Yi, Seung Rim; Roh... NaN NaN
# 9  Taylor, Drew W.; Petrera, Massimo; Hendry, Mik... NaN NaN
#
#                                                   TI  \
# 0  Which Criteria Are Used to Clear Athletes to R...
# 1  PLATELET-RICH PLASMA IN ORTHOPAEDIC SURGERY A ...
# 2  Supplementary tibial fixation in anterior cruc...
# 3  Hamstring Autograft Versus Soft-Tissue Allogra...
# 4  Platelet-rich therapies for musculoskeletal so...
# 5  Femoral Tunnel Position on Conventional Magnet...
# 6  Single-Bundle Anterior Cruciate Ligament Recon...
# 7  Platelet-rich therapies for musculoskeletal so...
# 8  Hybrid Tibial Fixation for Anterior Cruciate L...
# 9  A Systematic Review of the Use of Platelet-Ric...
#
#                                                   SO  ...  \
# 0         SPORTS HEALTH-A MULTIDISCIPLINARY APPROACH  ...
# 1                                       JBJS REVIEWS  ...
# 2                          ACTA ORTHOPAEDICA BELGICA  ...
# 3  ARTHROSCOPY-THE JOURNAL OF ARTHROSCOPIC AND RE...  ...
# 4            COCHRANE DATABASE OF SYSTEMATIC REVIEWS  ...
# 5  ARTHROSCOPY-THE JOURNAL OF ARTHROSCOPIC AND RE...  ...
# 6  ARTHROSCOPY-THE JOURNAL OF ARTHROSCOPIC AND RE...  ...
# 7            COCHRANE DATABASE OF SYSTEMATIC REVIEWS  ...
# 8  ARTHROSCOPY-THE JOURNAL OF ARTHROSCOPIC AND RE...  ...
# 9                 CLINICAL JOURNAL OF SPORT MEDICINE  ...
#
#                                         WC  \
# 0                           Sport Sciences
# 1                     Orthopedics; Surgery
# 2                              Orthopedics
# 3     Orthopedics; Sport Sciences; Surgery
# 4             Medicine, General & Internal
# 5     Orthopedics; Sport Sciences; Surgery
# 6     Orthopedics; Sport Sciences; Surgery
# 7             Medicine, General & Internal
# 8     Orthopedics; Sport Sciences; Surgery
# 9  Orthopedics; Physiology; Sport Sciences
#
#                                                WE  \
# 0  Science Citation Index Expanded (SCI-EXPANDED)
# 1          Emerging Sources Citation Index (ESCI)
# 2  Science Citation Index Expanded (SCI-EXPANDED)
# 3  Science Citation Index Expanded (SCI-EXPANDED)
# 4  Science Citation Index Expanded (SCI-EXPANDED)
# 5  Science Citation Index Expanded (SCI-EXPANDED)
# 6  Science Citation Index Expanded (SCI-EXPANDED)
# 7  Science Citation Index Expanded (SCI-EXPANDED)
# 8  Science Citation Index Expanded (SCI-EXPANDED)
# 9  Science Citation Index Expanded (SCI-EXPANDED)
#
#                                         SC     GA          PM  \
# 0                           Sport Sciences  DV8NH  41703942.0
# 1                     Orthopedics; Surgery  FQ6QQ  28953136.0
# 2                              Orthopedics  DV4NL  27682300.0
# 3     Orthopedics; Sport Sciences; Surgery  AU8OK  25108904.0
# 4              General & Internal Medicine  AH1MP         NaN
# 5     Orthopedics; Sport Sciences; Surgery  145SW  23538044.0
# 6     Orthopedics; Sport Sciences; Surgery  098YE  23369444.0
# 7              General & Internal Medicine  282QW  24363098.0
# 8     Orthopedics; Sport Sciences; Surgery  017PK  22732367.0
# 9  Orthopedics; Physiology; Sport Sciences  786DY  21562414.0
#
#                 OA  HC  HP          DA                   UT
# 0  Green Submitted NaN NaN  2026-04-15  WOS:001693291600001
# 1              NaN NaN NaN  2026-04-15  WOS:000418489500007
# 2              NaN NaN NaN  2026-04-15  WOS:000382902200029
# 3              NaN NaN NaN  2026-04-15  WOS:000345855700016
# 4  Green Submitted NaN NaN  2026-04-15  WOS:000335885200025
# 5              NaN NaN NaN  2026-04-15  WOS:000319038900013
# 6              NaN NaN NaN  2026-04-15  WOS:000315584200019
# 7              NaN NaN NaN  2026-04-15  WOS:000329188500033
# 8              NaN NaN NaN  2026-04-15  WOS:000309602500029
# 9              NaN NaN NaN  2026-04-15  WOS:000292284700011
#
# [10 rows x 71 columns]
#   ï»¿PT                                                 AU  BA  BE  GP  \
# 0     J           Piri, E; Jafarnezhadgero, A; Dehghani, M NaN NaN NaN
# 1     J  Allende, F; Allahabadi, S; Sachdev, D; Gopinat... NaN NaN NaN
# 2     J  Zandiyeh, P; Parola, LR; Fleming, BC; Beveridg... NaN NaN NaN
# 3     J                               Rose, M; Crawford, D NaN NaN NaN
# 4     J         Li, J; Kong, FL; Gao, XD; Shen, Y; Gao, SJ NaN NaN NaN
# 5     J  Bottoni, CR; Smith, EL; Shaha, J; Shaha, SS; R... NaN NaN NaN
# 6     J  Cvetanovich, GL; Mascarenhas, R; Saccomanno, M... NaN NaN NaN
# 7     J  Lawhorn, KW; Howell, SM; Traina, SM; Gottlieb,... NaN NaN NaN
#
#                                                   AF  BF  CA  \
# 0  Piri, Ebrahim; Jafarnezhadgero, AmirAli; Dehgh... NaN NaN
# 1  Allende, Felicitas; Allahabadi, Sachin; Sachde... NaN NaN
# 2  Zandiyeh, Payam; Parola, Lauren R.; Fleming, B... NaN NaN
# 3                    Rose, Michael; Crawford, Dennis NaN NaN
# 4  Li, Jia; Kong, Fanlong; Gao, Xianda; Shen, Yon... NaN NaN
# 5  Bottoni, Craig R.; Smith, Eric L.; Shaha, Jame... NaN NaN
# 6  Cvetanovich, Gregory L.; Mascarenhas, Randy; S... NaN NaN
# 7  Lawhorn, Keith W.; Howell, Stephen M.; Traina,... NaN NaN
#
#                                                   TI  \
# 0  Effects of Insole Type and Fatigue on the Elec...
# 1  Comparing Clinical Outcomes and Knee Stability...
# 2  Wavelet analysis reveals differential lower li...
# 3  Allograft Maturation After Reconstruction of t...
# 4  Prospective Randomized Comparison of Knee Stab...
# 5  Autograft Versus Allograft Anterior Cruciate L...
# 6  Hamstring Autograft Versus Soft-Tissue Allogra...
# 7  The Effect of Graft Tissue on Anterior Cruciat...
#
#                                                   SO  ...  \
# 0                         ARCHIVES OF REHABILITATION  ...
# 1                AMERICAN JOURNAL OF SPORTS MEDICINE  ...
# 2                            JOURNAL OF BIOMECHANICS  ...
# 3             ORTHOPAEDIC JOURNAL OF SPORTS MEDICINE  ...
# 4  ARTHROSCOPY-THE JOURNAL OF ARTHROSCOPIC AND RE...  ...
# 5                AMERICAN JOURNAL OF SPORTS MEDICINE  ...
# 6  ARTHROSCOPY-THE JOURNAL OF ARTHROSCOPIC AND RE...  ...
# 7  ARTHROSCOPY-THE JOURNAL OF ARTHROSCOPIC AND RE...  ...
#
#                                      WC  \
# 0                        Rehabilitation
# 1           Orthopedics; Sport Sciences
# 2   Biophysics; Engineering, Biomedical
# 3           Orthopedics; Sport Sciences
# 4  Orthopedics; Sport Sciences; Surgery
# 5           Orthopedics; Sport Sciences
# 6  Orthopedics; Sport Sciences; Surgery
# 7  Orthopedics; Sport Sciences; Surgery
#
#                                                WE  \
# 0          Emerging Sources Citation Index (ESCI)
# 1  Science Citation Index Expanded (SCI-EXPANDED)
# 2  Science Citation Index Expanded (SCI-EXPANDED)
# 3  Science Citation Index Expanded (SCI-EXPANDED)
# 4  Science Citation Index Expanded (SCI-EXPANDED)
# 5  Science Citation Index Expanded (SCI-EXPANDED)
# 6  Science Citation Index Expanded (SCI-EXPANDED)
# 7  Science Citation Index Expanded (SCI-EXPANDED)
#
#                                      SC     GA          PM  \
# 0                        Rehabilitation  EC0TB         NaN
# 1           Orthopedics; Sport Sciences  O0G9V  38551115.0
# 2               Biophysics; Engineering  0X3ND  35114581.0
# 3           Orthopedics; Sport Sciences  FD3VP  28840143.0
# 4  Orthopedics; Sport Sciences; Surgery  EI1DY  27282110.0
# 5           Orthopedics; Sport Sciences  CS9WX  26311445.0
# 6  Orthopedics; Sport Sciences; Surgery  AU8OK  25108904.0
# 7  Orthopedics; Sport Sciences; Surgery  980MR  22840988.0
#
#                       OA  HC  HP          DA                   UT
# 0  Green Submitted, gold NaN NaN  2026-04-15  WOS:001697519800005
# 1                    NaN NaN NaN  2026-04-15  WOS:001193830600001
# 2        Green Submitted NaN NaN  2026-04-15  WOS:000789616600005
# 3  Green Submitted, gold NaN NaN  2026-04-15  WOS:000407460800001
# 4                    NaN NaN NaN  2026-04-15  WOS:000392217600025
# 5                    NaN NaN NaN  2026-04-15  WOS:000362445100023
# 6                    NaN NaN NaN  2026-04-15  WOS:000345855700016
# 7                    NaN NaN NaN  2026-04-15  WOS:000306897900011
#
# [8 rows x 71 columns]

# %% [markdown]
# **Define the names and data frames of the raw datasets**

# %%
pubmed = {
    "pm_bptb": pm_bptb,
    "pm_ht": pm_ht,
    "pm_qt": pm_qt,
    "pm_plt": pm_plt,
    "pm_at": pm_at,
    "pm_ta": pm_ta
}

embase = {
    "em_bptb": em_bptb,
    "em_ht": em_ht,
    "em_qt": em_qt,
    "em_plt": em_plt,
    "em_at": em_at,
    "em_ta": em_ta
}

wos = {
    "wos_bptb": wos_bptb,
    "wos_ht": wos_ht,
    "wos_qt": wos_qt,
    "wos_plt": wos_plt,
    "wos_at": wos_at,
    "wos_ta": wos_ta
}

# %% [markdown]
# **PubMed/MEDLINE**: Rename columns, clean and create new data frames from the raw datasets.

# %%
for name, df in pubmed.items():
    df.rename(columns = {
    	"id" : "id",
    	"pmid" : "pmid",
    	"PubDate" : "date",
    	"EPubDate" : "epubdate",
    	"Source" : "journal_abbr",
    	"AuthorList" : "authors",
    	"LastAuthor" : "last_author",
    	"Title" : "title",
    	"Volume" : "volume",
    	"Issue" : "issue",
    	"Pages" : "pages",
    	"LangList" : "language",
    	"NlmUniqueID" : "nlmuniqueid",
    	"ISSN" : "issn",
    	"ESSN" : "essn",
    	"PubTypeList" : "study_design",
    	"RecordStatus" : "recordstatus",
    	"PubStatus" : "pubstatus",
    	"Articlelds" : "articlelds",
    	"DOI" : "doi",
    	"History" : "history",
    	"References" : "references",
    	"HasAbstract" : "hasabstract",
    	"PmcRefCount" : "pmcrefcount",
    	"FullJournalName" : "journal",
    	"ELocationID" : "elocationid",
    	"SO" : "so",
    	"abstract" : "abstract",
    	"source" : "source",
    	"subgroup" : "subgroup"
    }, inplace = True)
    
    df["id"] = range(1, len(df)+1)
    
    df = pd.DataFrame({
        "id": df["id"],
        "pmid": df["pmid"],
        "source": "pubmed",
        "doi": df["doi"],
        "authors": df["authors"].str.replace(r"[\['\]]","",regex=True),
        "journal": df["journal"],
        "title": df["title"],
        "abstract": df["abstract"],
        "year": df["year"],
        "language": df["language"]
    })
    
    globals()[name] = df
    df.to_csv(f"./data/{name}.csv", encoding = "utf-8")
pubmed = pd.concat([pm_bptb, pm_ht, pm_qt, pm_plt, pm_at, pm_ta])
pubmed.to_csv(f"./data/pubmed.csv", encoding = "utf-8")

# %% [markdown]
# **Embase**: Rename columns, clean and create new data frames from the raw datasets.

# %%
for name, df in embase.items():
    df.rename(columns = {
    	"Title" : "title",
    	"Original Title" : "original_title",
    	"Author Names" : "authors",
    	"Author Addresses" : "author_addresses",
    	"Correspondence Address" : "correspondence_address",
    	"Editors" : "editors",
    	"AiP/IP Entry Date" : "aip/ip_entry_date",
    	"Full Record Entry Date" : "full_record_entry_date",
    	"Source" : "journal_full",
    	"Source title" : "journal",
    	"Publication Year" : "year",
    	"Volume" : "volume",
    	"Issue" : "issue",
    	"First Page" : "first_page",
    	"Last Page" : "last_page",
    	"Date of Publication" : "date",
    	"Publication Type" : "study_design",
    	"Conference Name" : "conference_name",
    	"Conference Location" : "conference_location",
    	"Conference Date" : "conference_date",
    	"Conference Editors" : "conference_editors",
    	"ISSN" : "issn",
    	"ISBN" : "isbn",
    	"Name" : "name",
    	"Location" : "location",
    	"Date" : "date",
    	"Editors" : "editors",
    	"Book Publisher" : "book_publisher",
    	"Abstract" : "abstract",
    	"Original Abstract" : "original_abstract",
    	"Author Keywords" : "author_keywords",
    	"Emtree Drug Index Terms (Major Focus)" : "emtree_drug_index_terms_(major_focus)",
    	"Emtree Drug Index Terms" : "emtree_drug_index_terms",
    	"Emtree Medical Index Terms (Major Focus)" : "emtree_medical_index_terms_(major_focus)",
    	"Emtree Medical Index Terms" : "emtree_medical_index_terms",
    	"Drug Tradenames" : "drug_tradenames",
    	"Drug Manufacturer" : "drug_manufacturer",
    	"Device Tradenames" : "device_tradenames",
    	"Device Manufacturer" : "device_manufacturer",
    	"CAS Registry Numbers" : "cas_registry_numbers",
    	"Molecular Sequence Numbers" : "molecular_sequence_numbers",
    	"Embase Classification" : "embase_classification",
    	"Clinical Trial Numbers" : "clinical_trial_numbers",
    	"Article Language" : "language",
    	"Summary Language" : "summary_language",
    	"Embase Accession ID" : "embase_accession_id",
    	"Medline PMID" : "pmid",
    	"PUI" : "pui",
    	"DOI" : "doi",
    	"Full Text Link" : "full_text_link",
    	"Embase Link" : "embase_link",
    	"Open URL Link" : "open_url_link",
    	"Copyright" : "copyright",
    	"source" : "source",
    	"subgroup" : "subgroup"
}, inplace = True)
    
    df["id"] = range(1, len(df)+1)

    df = pd.DataFrame({
        "id": df["id"],
        "pmid": df["pmid"],
        "doi": df["doi"],
        "source": "embase",
        "authors": df["authors"].str.replace(r"[\['\]]","",regex=True),
        "journal": df["journal"],
        "title": df["title"],
        "abstract": df["abstract"],
        "year": df["year"],
        "language": df["language"]
    })

    df['pmid'] = df['pmid'].astype(str)
    df['language'] = df['language'].str.replace(r"[\'\[\]]","", regex = True)
    df = df.fillna("", inplace = True)

    globals()[name] = df
    
    df.to_csv(f"./data/{name}.csv", encoding = "utf-8")
embase = pd.concat([em_bptb, em_ht, em_qt, em_plt, em_at, em_ta])
embase.to_csv(f"./data/embase.csv", encoding = "utf-8")

# %% [markdown]
# **Web of Science**: Rename columns, clean and create new data frames from the raw datasets.

# %%
for name, df in web_of_science.items():
    df.rename(columns = {
        "id": "id",
    	"ï»¿PT" : "study_design",
    	"AU" : "authors",
    	"BA" : "book_authors",
    	"BE" : "book_editors",
    	"GP" : "book_group_authors",
    	"AF" : "authors_full",
    	"BF" : "book_author_full_names",
    	"CA" : "group_authors",
    	"TI" : "title",
    	"SO" : "journal",
    	"SE" : "book_series_title",
    	"BS" : "book_series_subtitle",
    	"LA" : "language",
    	"DT" : "document_type",
    	"CT" : "conference_title",
    	"CY" : "conference_date",
    	"CL" : "conference_location",
    	"SP" : "conference_sponsor",
    	"HO" : "conference_host",
    	"DE" : "author_keywords",
    	"ID" : "keywords_plus",
    	"AB" : "abstract",
    	"C1" : "addresses",
    	"C3" : "affiliations",
    	"RP" : "reprint_addresses",
    	"EM" : "email_addresses",
    	"RI" : "researcher_ids",
    	"OI" : "orcids",
    	"FU" : "funding_orgs",
    	"FP" : "funding_name_preferred",
    	"FX" : "funding_text",
    	"CR" : "cited_references",
    	"NR" : "cited_reference_count",
    	"TC" : "times_cited, wos_core",
    	"Z9" : "times_cited, all_databases",
    	"U1" : "180_day_usage_count",
    	"U2" : "since_2013_usage_count",
    	"PU" : "publisher",
    	"PI" : "publisher_city",
    	"PA" : "publisher_address",
    	"SN" : "issn",
    	"EI" : "eissn",
    	"BN" : "isbn",
    	"J9" : "journal_9",
    	"JI" : "journal_abbr",
    	"PD" : "date",
    	"PY" : "year",
    	"VL" : "volume",
    	"IS" : "issue",
    	"PN" : "part_number",
    	"SU" : "supplement",
    	"SI" : "special_issue",
    	"MA" : "meeting_abstract",
    	"BP" : "start_page",
    	"EP" : "end_page",
    	"AR" : "article_number",
    	"DI" : "doi",
    	"DL" : "doi_link",
    	"D2" : "book_doi",
    	"EA" : "early_access_date",
    	"PG" : "number_of_pages",
    	"WC" : "wos_categories",
    	"WE" : "web_of_science_index",
    	"SC" : "research_areas",
    	"GA" : "ids_number",
    	"PM" : "pmid",
    	"OA" : "open_access_designations",
    	"HC" : "highly_cited_status",
    	"HP" : "hot_paper_status",
    	"DA" : "date_of_export",
    	"UT" : "ut (unique_wos_id)",
    	"source" : "source",
        "subgroup": "subgroup"
    }, inplace = True)

    df["id"] = range(1, len(df)+1)

    df = pd.DataFrame({
        "id": df["id"],
        "pmid": df["pmid"],
        "source": "web_of_science",
        "doi": df["doi"],
        "authors": df["authors"].str.replace(r"[\['\]]","",regex=True),
        "journal": df["journal"],
        "title": df["title"],
        "abstract": df["abstract"],
        "year": df["year"],
        "language": df["language"]
    })
    df['pmid'] = df['pmid'].astype(str)
    df['language'] = df['language'].str.replace(r"[\'\[\]]","", regex = True)
    df = df.fillna("", inplace = True)
    globals()[name] = df
    
    df.to_csv(f"./data/{name}.csv", encoding = "latin-1")
wos = pd.concat([wos_bptb, wos_ht, wos_qt, wos_plt, wos_at, wos_ta])
wos.to_csv(f"./data/wos.csv", encoding = "latin-1")

# %% [markdown]
# Combine dataframes by subgroup across databases and write them to CSV.

# %%
patellar = [pm_bptb, em_bptb, wos_bptb]
hamstring = [pm_ht, em_ht, wos_ht]
quadriceps = [pm_qt, em_qt, wos_qt]
peroneus = [pm_plt, em_plt, wos_plt]
achilles = [pm_at, em_at, wos_at]
tibialis = [pm_ta, em_ta, wos_ta]

# %%
bptb = pd.concat(patellar).to_csv(f"./data/patellar.csv", encoding = "utf-8")
ht = pd.concat(hamstring).to_csv(f"./data/hamstring.csv", encoding = "utf-8")
ta = pd.concat(quadriceps).to_csv(f"./data/tibialis.csv", encoding = "utf-8")
at = pd.concat(peroneus).to_csv(f"./data/achilles.csv", encoding = "utf-8")
plt = pd.concat(achilles).to_csv(f"./data/peroneus.csv", encoding = "utf-8")
qt = pd.concat(tibialis).to_csv(f"./data/quadriceps.csv", encoding = "utf-8")

# %% [markdown]
# Combine dataframes by database across subgroups and write them to CSV

# %%
subgroups = [patellar, hamstring, quadriceps, peroneus, achilles, tibialis]

# %%
pd.concat([pubmed, embase, wos]).to_csv(f"./data/records.csv", encoding = "utf-8")

# %% [markdown]
# <div align = "center">
# <a href="#protocol"><img alt="Protocol" src="https://img.shields.io/badge/Protocol-black?style=for-the-badge" /></a>
# <a href="#search_strategy"><img alt="Search Strategy" src="https://img.shields.io/badge/Search_Strategy-black?style=for-the-badge" /></a>
# <a href="#search"><img alt="Search" src="https://img.shields.io/badge/Search-black?style=for-the-badge" /></a>
# <a href="#deduplication"><img alt="Deduplication" src="https://img.shields.io/badge/Deduplication-black?style=for-the-badge" /></a>
# <a href="#screening"><img alt="Screening" src="https://img.shields.io/badge/Screening-black?style=for-the-badge" /></a>
# <a href="#title_abstract_screening"><img alt="Title abstract screening" src="https://img.shields.io/badge/Title_abstract_screening-black?style=for-the-badge&logo=&logoColor="/></a>
# </div>
#
# <a id="deduplication"></a>
# <h2 align="center" style="font-family:Times New Roman;font-variant: small-caps;">Deduplication</h2>

# %% [markdown]
# The 'gold-standard' or consensus agreement among researchers seems to converge on the idea that removal of duplicate records is best performed in a process that involves three ordered stages. The first is deduplication based on a unique record identifier, such as a digital object identifier (DOI) number, PubMed identifier (PMID) number, or clinicaltrials.gov (NCT) number. Then, as according to as described for the second stage, the remaining records were deduplicated based on a concatenated column consisting of the title, author, and year. The title was standardized by converting to sentence case, and punctuation marks and white spaces were removed. The character length was decreased to 50. For the authors column, the last name of the first author was chosen to be used. For the year of publication, the year was extracted from the date of publication in the electronic version of the journal and converted into a string data structure.
#
# input file(s): `records.csv`, output file(s): `doi_deduplicated.csv`,
# `pmid_deduplicated.csv`, `title+author+year_deduplicated.csv`, and `title+year_deduplicated.csv`.

# %%
import pandas as pd
import mermaid
import os

input_file_name = f"{root}/systematic_review/deduplication/records.csv"

#input_file_name = f"{deduplication}/" + input('Enter file name: ') + '.csv'

deduplication = f"{root}/systematic_review/deduplication",

df = pd.read_csv(input_file_name) # A (records)
cols_input = input('Enter the column for which to deduplicate based on: ')
cols = [c.strip() for c in cols_input.split(',')]
folder = '_'.join(cols)
os.makedirs(f"{deduplication}/{folder}/", exist_ok = True)

output_file = f"{deduplication}/{folder}/{folder}_deduplicated"
output_file_name = f"{output_file}.csv"
output_for_recycle = f"{deduplication}/{folder}_deduplicated.csv"
prisma_file_name = f"{output_file}.mmd"

nulls_mask = df[cols].isnull().any(axis=1)
df_nulls = df[nulls_mask] # B
df_non_nulls = df[~nulls_mask] # C

duplicates_mask = df_non_nulls.duplicated(subset = cols, keep = False)
df_non_duplicates = df_non_nulls[~duplicates_mask] # D
df_duplicates = df_non_nulls[duplicates_mask] # E
#df_duplicates.groupby(cols, as_index=False).agg(agg_map)
df_kept = df_duplicates.drop_duplicates(subset = cols, keep = 'first')
#df_kept = df_duplicates.groupby(cols, as_index=False).agg(lambda s: list(dict.fromkeys(s.dropna())) if s.name in ['subgroup', 'source'] else s.dropna().iloc[0] if len(s.dropna()) else pd.NA)
#df_kept = df_duplicates.groupby(cols, as_index=False).agg(lambda s: list(dict.fromkeys(s.dropna())) if s.name == 'subgroup' else s.dropna().iloc[0] if len(s.dropna()) else pd.NA)
df_removed = df_duplicates[~df_duplicates.index.isin(df_kept.index)]
#df_kept = df_duplicates.groupby(cols, as_index=False).agg(lambda s: '; '.join(dict.fromkeys(s.dropna().astype(str).str.strip())) if s.name == 'subgroup' and s.dropna().astype(str).str.strip().nunique() > 1 else (s.dropna().astype(str).str.strip().iloc[0] if len(s.dropna().astype(str).str.strip()) else pd.NA))
df_unique = df_non_nulls.drop_duplicates(subset = cols, keep = 'first') # df of unique
df_deduplicated = pd.concat([df_non_duplicates, df_kept, df_nulls], ignore_index=True) # df of unique + df of non-duplicates

results = {"records": len(df),  
"nulls": len(df_nulls), 
"non_nulls": len(df_non_nulls), 
"non_duplicates": len(df_non_duplicates), 
"duplicates": len(df_duplicates), 
"removed": len(df_removed), 
"kept": len(df_kept),
"unique": len(df_unique),
"deduplicated": len(df_deduplicated)
}

output_file_name = f"{deduplication}/deduplicated.csv"
df_nulls.to_csv(output_file_name.replace('deduplicated','nulls'), index = False)
df_deduplicated.to_csv(output_file_name, index = False)
df_removed.to_csv(output_file_name.replace('deduplicated','duplicates_removed'), index = False)
df_deduplicated.to_csv(output_for_recycle, index = False)

graph_text = f"""---
config:
theme: neutral
curve: stepBefore
---
graph TD;
A["`**records** (*n* = {results['records']})`"];
B["`null (*n* = {results['nulls']})`"];
C["`non-null (*n* = {results['non_nulls']})`"];
D["`non-duplicates (*n* = {results['non_duplicates']})`"];
E["`duplicates (*n* = {results['duplicates']})`"];
F["`duplicates kept (*n* = {results['kept']})`"];
G["`duplicates removed (*n* = {results['removed']})`"];
H["`unique (*n* = {results['unique']})`"];
I["`deduplicated (*n* = {results['deduplicated']})`"];

A --> B & C;
C --> D & E;
E --> F & G;
D & F --> H
B & H --> I"""

with open(prisma_file_name, "w") as f:
    f.write(graph_text)

# !mmdc -i "{prisma_file_name}" -o "{output_file}"_light.svg
# !mmdc -i "{prisma_file_name}" -o "{output_file}"_dark.svg -t dark -b transparent
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import pandas as pd
#       2 import mermaid
#       3 import os
#       4
# ----> 5 input_file_name = f"{root}/systematic_review/deduplication/records.csv"
#       6
#       7 #input_file_name = f"{deduplication}/" + input('Enter file name: ') + '.csv'
#       8
#
# NameError: name 'root' is not defined

# %% [markdown]
# <div align = "center">
# <a href="#protocol"><img alt="Protocol" src="https://img.shields.io/badge/Protocol-black?style=for-the-badge" /></a>
# <a href="#search_strategy"><img alt="Search Strategy" src="https://img.shields.io/badge/Search_Strategy-black?style=for-the-badge" /></a>
# <a href="#search"><img alt="Search" src="https://img.shields.io/badge/Search-black?style=for-the-badge" /></a>
# <a href="#deduplication"><img alt="Deduplication" src="https://img.shields.io/badge/Deduplication-black?style=for-the-badge" /></a>
# <a href="#screening"><img alt="Screening" src="https://img.shields.io/badge/Screening-black?style=for-the-badge" /></a>
# <a href="#title_abstract_screening"><img alt="Title abstract screening" src="https://img.shields.io/badge/Title_abstract_screening-black?style=for-the-badge&logo=&logoColor="/></a>
# </div>
#
# <a id="screening"></a>
#
# <h2 align="center" style="font-family:Times New Roman;font-variant: small-caps;">Screening</h2>
#
# ---

# %% [markdown]
# <a id="title_abstract_screening"></a>
#
# <h3 align="center" style="font-family:Times New Roman;font-variant:small-caps;">Title abstract screening</h3>

# %%
# %pip install -q ipywidgets
import ipywidgets as widgets
import pandas as pd

df = csv2df('records')

df = pd.read_csv(f"./records.csv", encoding = "utf-8")
columns = df.columns
", ".join(columns)

text = f"""id, source_id, study, subgroup, authors, first_author, title, short_title, abstract, year, language, journal, source, doi, doi_url, pmid, pmid_url, title+author+year, title+year, second_author, num_authors'"""
list = text.split(", ")
list

A = widgets.IntText(value=0, description="Study ID ", layout={"width":"20%"})
B = widgets.HTML(value="", layout={"width":"80%", "height":"100%"})
C = widgets.HTML(value="", layout={"width":"80%", "height":"100%"})

def update(change):
    title = df.loc[df["id"] == A.value, "title"]
    abstract = df.loc[df["id"] == A.value, "abstract"]

    if  A.value > 0:
        B.value = f"<p>{str(title.iloc[0])}</p>"
        C.value = f"<p>{str(abstract.iloc[0])}</p>"
    else:
        B.value = ""
        C.value = ""

A.observe(update, names="value")

Yes = widgets.Button(value = "Yes", description = "Yes")
Maybe = widgets.Button(value = "Maybe", description = "Maybe")
No = widgets.Button(value = "No", description = "No")

Label = widgets.Label(value = "Result of Title / Abstract screening ")
items = [A, Label, Yes, No]

D = widgets.HBox(items, layout = {"width":"100%"})

screening = display(D, B, C)
update(None)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 get_ipython().run_line_magic('pip', 'install -q ipywidgets')
#       2 import ipywidgets as widgets
#       3 import pandas as pd
#       4
# ----> 5 df = csv2df('records')
#       6
#       7 df = pd.read_csv(f"./records.csv", encoding = "utf-8")
#       8 columns = df.columns
#
# NameError: name 'csv2df' is not defined

# %% [markdown]
# Screening filter #1: Language

# %%
df = pd.read_csv(f"{deduplication}/title+year_deduplicated.csv", encoding = "utf-8")
                
df.to_csv(f"{screening}/screening.csv", encoding = "utf-8")
df.sort_values(by = ['subgroup', 'year', 'authors'])

dict = {"language": "English"}
import pandas as pd
import os
print(df['pmid'])
for x, y in dict.items():
    mask = df[x].astype(str).str.contains(y, case=False, na=False)
    true = df[mask]
    false = df[~mask]
    folder = f"{title_abstract}/{x}"
    os.makedirs(folder, exist_ok = True)
    file = f"{y}"
    true.to_csv(f"{folder}/{file}.csv", encoding = "utf-8")
    false.to_csv(f"{folder}/non_{file}.csv", encoding = "utf-8")
    print(f"Number of records that contain '{y}' in column {x}: ",len(true))
    print(f"Number of records that don't contain '{y}' in column '{x}': ",len(false))

# %%
df.head()

# %% [markdown]
# Screening filter #2: Randomized controlled trials

# %%
# Screen for 'randomized' in a newly made 'title and abstract' column
df = true
df['tiab'] = df['title'] + " " + df['abstract']
dict = {"tiab": "random"}
for x, y in dict.items():
    mask = df[x].astype(str).str.contains(y, case=False, na=False)
    true = df[mask]
    false = df[~mask]
    folder = f"{title_abstract}/{x}"
    os.makedirs(folder, exist_ok = True)
    file = f"{y}"
    true.to_csv(f"{folder}/{file}.csv", encoding = "utf-8")
    false.to_csv(f"{folder}/non_{file}.csv", encoding = "utf-8")
    print(f"Number of records that contain '{y}' in column {x}: ",len(true))
    print(f"Number of records that don't contain '{y}' in column '{x}': ",len(false))

# %% [markdown]
# Screening filter #3: Clinical trials (unpublished and without results)

# %%
# Screen out unpublished clinical trials from "clinicaltrials.gov" (only published RCTs, from peer-reviewed journals included)
df = true
dict = {"journal": "clinicaltrials.gov"}
for x, y in dict.items():
    mask = df[x].astype(str).str.contains(y, case=False, na=False)
    true = df[mask]
    false = df[~mask]
    folder = f"{title_abstract}/{x}"
    os.makedirs(folder, exist_ok = True)
    file = f"{y}"
    true.to_csv(f"{folder}/{file}.csv", encoding = "utf-8")
    false.to_csv(f"{folder}/non_{file}.csv", encoding = "utf-8")
    print(f"Number of records that contain '{y}' in column {x}: ",len(true))
    print(f"Number of records that don't contain '{y}' in column '{x}': ",len(false))

# %%
df = false
df.to_csv(f"{full_text}/full_text_screening.csv", encoding = "utf-8")

# %% [markdown]
# ---
# [top](#toc) | [search strategy](#search-strategy) | [search](#search) | [deduplication](#deduplication) | [screening](#screening) |
# [data collection](#data-collection) |
#
# <a id="Full-text screening"></a>
#
# <h3 align="center" style="font-family:Times New Roman;font-variant:small-caps;">Full-text screening</h3>

# %%
import requests
import pandas as pd

df = pd.read_csv(f"{full_text}/full_text_screening.csv", encoding = "utf-8")

doi = df["doi"].fillna("").str.strip()
print(doi)

#sci = df["doi"].where(df["year"]==2010).dropna()

downloads = []
views = []
for x in doi:
    base = f"sci.bban.top/pdf" # options = sci-hub.al
    download = f"https://{base}/{x}.pdf?download=true"
    view = f"https://{base}/{x}.pdf"
    downloads.append(download)
    views.append(view)

df["pdf.download"] = downloads
df["pdf.view"] = views
df.to_csv(f"{screening}/PDF/pdf.csv", encoding = "utf-8")
df.to_csv(f"{screening}/PDF/pdf.csv", encoding = "utf-8")
df.head()
display(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 4
#       1 import requests
#       2 import pandas as pd
#       3
# ----> 4 df = pd.read_csv(f"{full_text}/full_text_screening.csv", encoding = "utf-8")
#       5
#       6 doi = df["doi"].fillna("").str.strip()
#       7 print(doi)
#
# NameError: name 'full_text' is not defined

# %% [markdown]
# ---
# <div align = "center">
# <a href="#protocol"><img alt="Protocol" src="https://img.shields.io/badge/Protocol-black?style=for-the-badge" /></a>
# <a href="#search_strategy"><img alt="Search Strategy" src="https://img.shields.io/badge/Search_Strategy-black?style=for-the-badge" /></a>
# <a href="#search"><img alt="Search" src="https://img.shields.io/badge/Search-black?style=for-the-badge" /></a>
# <a href="#deduplication"><img alt="Deduplication" src="https://img.shields.io/badge/Deduplication-black?style=for-the-badge" /></a>
# <a href="#screening"><img alt="Screening" src="https://img.shields.io/badge/Screening-black?style=for-the-badge" /></a>
# <a href="#title_abstract_screening"><img alt="Title abstract screening" src="https://img.shields.io/badge/Title_abstract_screening-black?style=for-the-badge&logo=&logoColor="/></a>
# </div>
#
# <a id="data-collection"></a>
#
# <h1 align="center" style="font-family:Times New Roman;font-variant:small-caps;">Data Collection</h1>
